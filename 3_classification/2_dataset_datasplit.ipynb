# %%
import numpy as np
import pandas as pd
import os
from tqdm import tqdm as tqdm
import matplotlib.pyplot as plt
from torch.utils.data import Dataset

# %%
# Seed for reproducibility
SEED = 42
np.random.seed(SEED)

# Path to the .npz file
DATASET_PATH = "../../MLPC2025_classification"

ANNOTATIONS_PATH = DATASET_PATH + "/annotations.csv"
#ANNOTATIONS_TEXT_EMBEDDINGS_PATH = DATASET_PATH + "/annotations_text_embeddings.npz"

METADATA_PATH = DATASET_PATH + "/metadata.csv"
#METADATA_TITLE_EMBEDDINGS_PATH = DATASET_PATH + "/metadata_title_embeddings.npz"
#METADATA_KEYWORDS_EMBEDDINGS_PATH = DATASET_PATH + "/metadata_keywords_embeddings.npz"

AUDIO_PATHS = DATASET_PATH + "/audio"
AUDIO_FEATURES_PATHS = DATASET_PATH + "/audio_features"

LABELS_PATH = DATASET_PATH + "/labels"

# %%
annotations = pd.read_csv(ANNOTATIONS_PATH)
annotations.head()
# Out:
#      task_id    filename                                          annotator  \
# 0  161976549  117126.mp3  1145579747015607221221744067969991550764671773...
# 1  161976549  117126.mp3  1145579747015607221221744067969991550764671773...
# 2  161976550  118234.mp3  5022633589939139634134314703519782680423201448...
# 3  161976550  118234.mp3  5022633589939139634134314703519782680423201448...
# 4  161976551  119173.mp3  8105077500224920444298835829881210427871190692...
#
#                                                 text      onset     offset  \
# 0  An alarm is ringing loudly and repeatedly nearby.   0.000000  10.503064
# 1             An alarm is ringing repeatedly nearby.  12.514616  23.048000
# 2            An alarm clock is beeping continuously.   0.000000  13.414880
# 3            An alarm clock is beeping continuously.  15.134252  28.492000
# 4     A car alarm sounds loudly in a steady pattern.   0.000000  20.065604
#
#        time                                   original_caption  \
# 0   345.033     Raw loud alarm sound repeatedly ringing nearby
# 1   345.033        Clean alarm sound repeatedly ringing nearby
# 2   919.016                    Alarm clock beeping continuesly
# 3   919.016                    Alarm clock beeping continuesly
# 4  2162.620  a car alarm sounds loudly in a steady pattern ...
#
#                 categories
# 0                ['Alarm']
# 1                ['Alarm']
# 2  ['Alarm', 'Beep/Bleep']
# 3  ['Alarm', 'Beep/Bleep']
# 4         ['Alarm', 'Car']

# %%
# Remove unnecessary columns for this task
annotations = annotations.drop(columns=['task_id'])
annotations['original_index'] = annotations.index
annotations.head()
# Out:
#      filename                                          annotator  \
# 0  117126.mp3  1145579747015607221221744067969991550764671773...
# 1  117126.mp3  1145579747015607221221744067969991550764671773...
# 2  118234.mp3  5022633589939139634134314703519782680423201448...
# 3  118234.mp3  5022633589939139634134314703519782680423201448...
# 4  119173.mp3  8105077500224920444298835829881210427871190692...
#
#                                                 text      onset     offset  \
# 0  An alarm is ringing loudly and repeatedly nearby.   0.000000  10.503064
# 1             An alarm is ringing repeatedly nearby.  12.514616  23.048000
# 2            An alarm clock is beeping continuously.   0.000000  13.414880
# 3            An alarm clock is beeping continuously.  15.134252  28.492000
# 4     A car alarm sounds loudly in a steady pattern.   0.000000  20.065604
#
#        time                                   original_caption  \
# 0   345.033     Raw loud alarm sound repeatedly ringing nearby
# 1   345.033        Clean alarm sound repeatedly ringing nearby
# 2   919.016                    Alarm clock beeping continuesly
# 3   919.016                    Alarm clock beeping continuesly
# 4  2162.620  a car alarm sounds loudly in a steady pattern ...
#
#                 categories  original_index
# 0                ['Alarm']               0
# 1                ['Alarm']               1
# 2  ['Alarm', 'Beep/Bleep']               2
# 3  ['Alarm', 'Beep/Bleep']               3
# 4         ['Alarm', 'Car']               4

# %%
metadata = pd.read_csv(METADATA_PATH)
metadata.head()
# Out:
#      filename                                           keywords  \
# 0  321771.mp3      Interior, AMB, Italy, Distant, Speech, Reverb
# 1  451371.mp3  kids, throaty, crowd, India, distant, traffic,...
# 2  199414.mp3                           broadcast, speech, radio
# 3  410952.mp3            loop2017, atmos, dolby, speech, ableton
# 4  203908.mp3  dr-40, project, speech, student, italian, reci...
#
#    freesound_id                                         sound_link  \
# 0        321771  https://freesound.org/people/Skjor1/sounds/321...
# 1        451371  https://freesound.org/people/kyles/sounds/451371/
# 2        199414  https://freesound.org/people/martinimeniscus/s...
# 3        410952  https://freesound.org/people/lietoofine/sounds...
# 4        203908  https://freesound.org/people/s9ames/sounds/203...
#
#       manufacturer                                            license  \
# 0           Skjor1  http://creativecommons.org/publicdomain/zero/1.0/
# 1            kyles  http://creativecommons.org/publicdomain/zero/1.0/
# 2  martinimeniscus  http://creativecommons.org/publicdomain/zero/1.0/
# 3       lietoofine       https://creativecommons.org/licenses/by/4.0/
# 4           s9ames        http://creativecommons.org/licenses/by/3.0/
#
#                                                title  \
# 0  Interior Ambience + Distant Reverberant Speech...
# 1  election rally crowd and speech with distant t...
# 2      Old Radio Speech Background, higher FF125.aif
# 3                             dolby atmos speech.wav
# 4                            bologna speech Italian2
#
#                                          description  num_downloads  \
# 0  Interior Ambience + Distant Reverberant Speech...            120
# 1  election rally crowd and speech with distant t...            122
# 2  Background noise for an old radio broadcast sp...            391
# 3                       dolby atmos speech @Loop2017            193
# 4  recorded with a tascam dr-40 in a sound studio...            526
#
#                 geotag  start_time_s  end_time_s
# 0                  NaN         5.200      27.179
# 1                  NaN       120.800     144.984
# 2                  NaN       102.003     130.921
# 3  52.479543 13.500279        31.330      54.021
# 4                  NaN        29.200      45.689

# %%
# Remove unnecessary columns for this task
metadata = metadata.drop(columns=['freesound_id', 'sound_link', 'manufacturer', 'license', 'num_downloads', 'geotag', 'start_time_s', 'end_time_s'])
metadata.head()
# Out:
#      filename                                           keywords  \
# 0  321771.mp3      Interior, AMB, Italy, Distant, Speech, Reverb
# 1  451371.mp3  kids, throaty, crowd, India, distant, traffic,...
# 2  199414.mp3                           broadcast, speech, radio
# 3  410952.mp3            loop2017, atmos, dolby, speech, ableton
# 4  203908.mp3  dr-40, project, speech, student, italian, reci...
#
#                                                title  \
# 0  Interior Ambience + Distant Reverberant Speech...
# 1  election rally crowd and speech with distant t...
# 2      Old Radio Speech Background, higher FF125.aif
# 3                             dolby atmos speech.wav
# 4                            bologna speech Italian2
#
#                                          description
# 0  Interior Ambience + Distant Reverberant Speech...
# 1  election rally crowd and speech with distant t...
# 2  Background noise for an old radio broadcast sp...
# 3                       dolby atmos speech @Loop2017
# 4  recorded with a tascam dr-40 in a sound studio...

# %%
# Load audio features
all_audio_file_basenames = [os.path.splitext(os.path.basename(name))[0] for name in os.listdir(AUDIO_PATHS) if name.endswith('.mp3')]
all_audio_file_features = {}
for audio_file_basename in tqdm(all_audio_file_basenames):
    features_path = os.path.join(AUDIO_FEATURES_PATHS, audio_file_basename + '.npz')
    features = dict(np.load(features_path))
    all_audio_file_features[audio_file_basename] = features
# Out:
# 100%|██████████| 8230/8230 [00:22<00:00, 358.19it/s]

# %%
# Load audio labels
all_audio_file_basenames = [os.path.splitext(os.path.basename(name))[0] for name in os.listdir(AUDIO_PATHS) if name.endswith('.mp3')]
all_audio_file_labels = {}
for audio_file_basename in tqdm(all_audio_file_basenames):
    labels_path = os.path.join(LABELS_PATH, audio_file_basename + '_labels.npz')
    labels = dict(np.load(labels_path))
    all_audio_file_labels[audio_file_basename] = labels
# Out:
# 100%|██████████| 8230/8230 [00:59<00:00, 138.37it/s]

# %%
example_audio_file = all_audio_file_basenames[0]
example_audio_features = all_audio_file_features[example_audio_file]
example_audio_labels = all_audio_file_labels[example_audio_file]

all_audio_feature_names = list(example_audio_features.keys())
all_audio_label_names = list(example_audio_labels.keys())

print(f'All audio features: n={len(all_audio_feature_names)}')
print(f'\t{all_audio_feature_names}')

print(f'\nAll audio labels: n={len(all_audio_label_names)}')
print(f'\t{all_audio_label_names}')
# Out:
# All audio features: n=13
# 	['embeddings', 'melspectrogram', 'mfcc', 'mfcc_delta', 'mfcc_delta2', 'flatness', 'centroid', 'flux', 'energy', 'power', 'bandwidth', 'contrast', 'zerocrossingrate']
#
# All audio labels: n=58
# 	['Airplane', 'Alarm', 'Beep/Bleep', 'Bell', 'Bicycle', 'Bird Chirp', 'Bus', 'Car', 'Cat Meow', 'Chainsaw', 'Clapping', 'Cough', 'Cow Moo', 'Cowbell', 'Crying', 'Dog Bark', 'Doorbell', 'Drip', 'Drums', 'Fire', 'Footsteps', 'Guitar', 'Hammer', 'Helicopter', 'Hiccup', 'Horn Honk', 'Horse Neigh', 'Insect Buzz', 'Jackhammer', 'Laughter', 'Lawn Mower', 'Motorcycle', 'Piano', 'Pig Oink', 'Power Drill', 'Power Saw', 'Rain', 'Rooster Crow', 'Saxophone', 'Sewing Machine', 'Sheep/Goat Bleat', 'Ship/Boat', 'Shout', 'Singing', 'Siren', 'Sneeze', 'Snoring', 'Speech', 'Stream/River', 'Thunder', 'Train', 'Truck', 'Trumpet', 'Vacuum Cleaner', 'Violin', 'Washing Machine', 'Waves', 'Wind']

# %%
# Check label distribution
files_per_label = {label_name: 0 for label_name in all_audio_label_names}
for audio_file_basename in all_audio_file_basenames:
    for label_name, label_values in all_audio_file_labels[audio_file_basename].items():
        if np.sum(label_values) > 0:
            files_per_label[label_name] += 1

label_counts = sorted(list(files_per_label.items()), key=lambda x: x[1], reverse=True)

labels = [label for label, count in label_counts]
counts = [count for label, count in label_counts]

plt.figure(figsize=(12, 6))
plt.bar(labels, counts, color='skyblue')
plt.xlabel('Labels')
plt.ylabel('Number of Files')
plt.title('Label Distribution over Files')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# Idea for splitting the data:
#
# Use some fixed percentages for training, validation, and test sets (e.g., 70% training, 15% validation, 15% test).
# Then, for each label, ensure that the same percentage of files is allocated to each set. This way, you maintain the label distribution across all sets.
#
# Additionally, some resampling (e.g. SMOTE), undersampling (e.g. RUS, TOMEK) or class weighting techniques can be applied to maintain balance during training.

# %%
class AudioClassificationDataset(Dataset):

    def __init__(self, data_dir, audio_features_subset, return_snippets, context_length, testing):
        """
        data_dir: Path to the dataset directory
        audio_features_subset: List of audio features to be used
        return_snippets: If False, return whole files, if True, return snippets of size context_length
        context_length: Length of the snippets to be returned (ideally uneven number)
        testing: If True, use a small subset of the audio files for testing
        """

        self.return_snippets = return_snippets
        self.context_length = context_length

        audio_path = os.path.join(data_dir, 'audio')

        # For testing purposes, use a smaller subset of the audio files (just copy some audio files from the audio directory
        # to a new directory at the same level)
        #audio_path = os.path.join(data_dir, 'audio_subset_test')

        self.audio_file_basenames = [os.path.splitext(os.path.basename(name))[0] for name in os.listdir(audio_path) if name.endswith('.mp3')]
        self.audio_file_features = []
        self.audio_file_labels = []

        for audio_file_idx, audio_file_basename in enumerate(tqdm(self.audio_file_basenames)):

            # Remove unwanted features and store remaining features
            audio_features_dict = dict(np.load(os.path.join(data_dir, 'audio_features', audio_file_basename + '.npz')))
            audio_features = [audio_features_dict[wanted_feature] for wanted_feature in audio_features_subset]

            n_frames = audio_features[0].shape[0]

            # store whole file at once
            if not self.return_snippets:
                self.audio_file_features.append(audio_features)
            # store single snippets
            else:
                # Pad so that edge-frames have context
                padding = ((context_length//2, context_length//2), (0, 0))
                audio_features = [np.pad(array=feature, pad_width=padding, mode='constant', constant_values=0) for feature in audio_features]

                for frame_idx in range(n_frames):
                    frame_features = [audio_feature[frame_idx:frame_idx + context_length] for audio_feature in audio_features]
                    self.audio_file_features.append((audio_file_idx, frame_idx, frame_features))

            # Store labels
            audio_labels_dict = dict(np.load(os.path.join(data_dir, 'labels', audio_file_basename + '_labels.npz')))

            n_labels = len(audio_labels_dict.keys())
            file_labels = np.zeros((n_frames, n_labels))
            for i, (label_name, label_values) in enumerate(audio_labels_dict.items()):

                # If there are multiple label sets -> multiple annotators
                if label_values.shape[1] != 1:
                    # Like discussed in the exercise class, we choose one at random
                    label_values = label_values[:, np.random.randint(0, label_values.shape[1]), np.newaxis]

                file_labels[:, i] = label_values[:, 0]

            # store labels for whole file at once
            if not self.return_snippets:
                self.audio_file_labels.append(file_labels)
            # store labels for single snippets
            else:
                for frame_idx, frame_labels in enumerate(file_labels):
                    self.audio_file_labels.append((audio_file_idx, frame_idx, frame_labels))

            if testing and audio_file_idx == 1000:
                break

    def __len__(self):
            return len(self.audio_file_labels)

    def __getitem__(self, idx):
        if not self.return_snippets:
            return self.audio_file_basenames[idx], self.audio_file_features[idx], self.audio_file_labels[idx]
        else:
            file_idx, frame_idx, frame_features = self.audio_file_features[idx]
            file_idx, frame_idx, frame_labels = self.audio_file_labels[idx]
            return file_idx, self.audio_file_basenames[file_idx], frame_idx, frame_features, frame_labels

# %%
data = AudioClassificationDataset(
    data_dir = DATASET_PATH,
    audio_features_subset = ['mfcc', 'melspectrogram'],
    return_snippets = True,
    context_length = 3,
    testing = False
)
print(f"Dataset size: {len(data)}")
# Out:
# 100%|██████████| 8230/8230 [02:00<00:00, 68.16it/s]
# Dataset size: 1538577

# %%
def custom_train_test_split(custom_dataset, val_size=0.2, test_size=0.2):
    # Creates a dataset split for training, validation and test set, while keeping contents from one file contained in one set,
    # like was discussed in the exercise session

    n_files = len(custom_dataset.audio_file_basenames)
    dataset_size = len(custom_dataset)

    if custom_dataset.return_snippets:

        # For each file get the index of the first frame
        file_start_end_index_dict = {}

        for idx, (file_idx, frame_idx, _) in enumerate(custom_dataset.audio_file_labels):
            if idx == 0 and frame_idx == 0:
                file_start_end_index_dict[file_idx] = [idx, None]
            elif idx != 0 and frame_idx == 0:
                file_start_end_index_dict[file_idx] = [idx, None]
                file_start_end_index_dict[file_idx-1][1] = idx
            elif idx == dataset_size - 1:
                file_start_end_index_dict[file_idx][1] = idx

        # Get indices of files for which to include the snippets in the splits
        file_indices = list(range(n_files))
        np.random.shuffle(file_indices)
        shuffled_file_indices = file_indices

        train_size_files = n_files - int(n_files * (val_size + test_size))
        val_size_files = int(n_files * val_size)

        train_file_indices = shuffled_file_indices[:train_size_files]
        val_file_indices = shuffled_file_indices[train_size_files:(train_size_files+val_size_files)]
        test_file_indices = shuffled_file_indices[(train_size_files+val_size_files):]

        # For each file index in the lists get corresponding indices of the snippets
        indices = []
        for i, file_indices in enumerate([train_file_indices, val_file_indices, test_file_indices]):
            indices.append([])
            for file_idx in file_indices:
                start_idx, end_idx = file_start_end_index_dict[file_idx]
                indices[i].extend(list(range(start_idx, end_idx)))

        train_indices = indices[0]
        val_indices = indices[1]
        test_indices = indices[2]


    else: # 1 to 1 correspondence between files and dataset entries
        indices = list(range(dataset_size))
        np.random.shuffle(indices)
        shuffled_indices = indices

        train_size = dataset_size - int(dataset_size * (val_size + test_size))
        val_size = int(dataset_size * val_size)

        train_indices = shuffled_indices[:train_size]
        val_indices = shuffled_indices[train_size:(train_size+val_size)]
        test_indices = shuffled_indices[(train_size+val_size):]


    return train_indices, val_indices, test_indices

# %%
train, test, val = custom_train_test_split(data, val_size=0.2, test_size=0.2)
print("Train, test and validation set sizes:")
print(f"-Train: {len(train)}")
print(f"-Test: {len(test)}")
print(f"-Validation: {len(val)}")
# Out:
# Train, test and validation set sizes:
# -Train: 923744
# -Test: 304650
# -Validation: 310182

# %%
print("This is what the data looks like:")
for i, idx in enumerate(train):
    if data.return_snippets == False:
        audio_name, features, labels = data[idx]
        print(f"Name: {audio_name}, Feature dim: {[f.shape for f in features]}, Label dim: {labels.shape}")
    elif data.return_snippets == True:
        file_idx, audio_name, frame_idx, features, labels = data[idx]
        print(f"Name: {audio_name}, Frame: {frame_idx}, Feature dim: {[f.shape for f in features]}, Label dim: {labels.shape}")

    if i > 1000:
        break
# Out:
# This is what the data looks like:
# Name: 636862, Frame: 0, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 1, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 2, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 3, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 4, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 5, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 6, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 7, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 8, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 9, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 10, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 11, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 12, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 13, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 14, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 15, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 16, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 17, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 18, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 19, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 20, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 21, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 22, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 23, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 24, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 25, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 26, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 27, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 28, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 29, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 30, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 31, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 32, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 33, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 34, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 35, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 36, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 37, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 38, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 39, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 40, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 41, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 42, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 43, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 44, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 45, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 46, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 47, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 48, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 49, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 50, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 51, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 52, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 53, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 54, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 55, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 56, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 57, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 58, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 59, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 60, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 61, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 62, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 63, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 64, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 65, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 66, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 67, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 68, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 69, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 70, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 71, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 72, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 73, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 74, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 75, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 76, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 77, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 78, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 79, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 80, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 81, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 82, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 83, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 84, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 85, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 86, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 87, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 88, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 89, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 90, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 91, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 92, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 93, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 94, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 95, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 96, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 97, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 98, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 99, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 100, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 101, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 102, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 103, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 104, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 105, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 106, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 107, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 108, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 109, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 110, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 111, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 112, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 113, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 114, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 115, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 116, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 117, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 118, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 119, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 120, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 121, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 122, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 123, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 124, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 125, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 126, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 127, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 128, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 129, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 130, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 131, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 132, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 133, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 134, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 135, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 136, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 137, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 138, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 139, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 140, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 141, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 142, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 143, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 144, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 145, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 146, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 147, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 148, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 149, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 150, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 151, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 152, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 153, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 154, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 155, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 156, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 157, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 158, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 159, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 160, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 161, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 162, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 163, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 164, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 165, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 166, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 167, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 168, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 169, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 170, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 171, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 172, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 173, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 174, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 175, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 176, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 177, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 178, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 179, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 180, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 181, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 182, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 183, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 184, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 185, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 186, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 187, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 188, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 189, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 190, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 191, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 192, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 193, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 194, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 195, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 196, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 197, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 198, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 199, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 200, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 201, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 202, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 203, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 204, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 205, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 206, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 207, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 208, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 209, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 210, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 211, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 212, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 213, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 214, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 215, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 216, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 217, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 218, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 219, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 220, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 221, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 222, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 223, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 224, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 225, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 226, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 227, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 228, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 229, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 230, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 231, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 232, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 233, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 234, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 235, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 236, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 237, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 238, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 239, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 636862, Frame: 240, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 0, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 1, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 2, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 3, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 4, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 5, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 6, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 7, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 8, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 9, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 10, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 11, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 12, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 13, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 14, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 15, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 16, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 17, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 18, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 19, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 20, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 21, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 22, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 23, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 24, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 25, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 26, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 27, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 28, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 29, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 30, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 31, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 32, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 33, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 34, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 35, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 36, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 37, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 38, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 39, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 40, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 41, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 42, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 43, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 44, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 45, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 46, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 47, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 48, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 49, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 50, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 51, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 52, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 53, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 54, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 55, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 56, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 57, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 58, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 59, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 60, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 61, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 62, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 63, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 64, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 65, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 66, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 67, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 68, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 69, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 70, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 71, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 72, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 73, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 74, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 75, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 76, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 77, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 78, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 79, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 80, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 81, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 82, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 83, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 84, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 85, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 86, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 87, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 88, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 89, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 90, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 91, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 92, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 93, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 94, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 95, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 96, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 97, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 98, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 99, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 100, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 101, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 102, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 103, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 104, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 105, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 106, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 107, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 108, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 109, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 110, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 111, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 112, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 113, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 114, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 115, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 116, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 117, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 118, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 119, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 120, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 121, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 122, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 123, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 124, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 125, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 126, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 127, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 128, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 129, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 130, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 131, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 132, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 133, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 134, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 135, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 136, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 137, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 138, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 139, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 140, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 141, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 142, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 143, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 144, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 145, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 146, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 147, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 148, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 149, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 150, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 151, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 152, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 153, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 154, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 155, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 156, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 157, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 158, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 159, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 160, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 161, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 162, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 163, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 164, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 165, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 166, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 167, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 168, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 169, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 170, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 171, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 172, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 171471, Frame: 173, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 0, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 1, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 2, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 3, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 4, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 5, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 6, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 7, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 8, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 9, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 10, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 11, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 12, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 13, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 14, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 15, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 16, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 17, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 18, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 19, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 20, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 21, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 22, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 23, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 24, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 25, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 26, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 27, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 28, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 29, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 30, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 31, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 32, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 33, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 34, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 35, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 36, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 37, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 38, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 39, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 40, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 41, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 42, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 43, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 44, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 45, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 46, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 47, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 48, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 49, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 50, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 51, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 52, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 53, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 54, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 55, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 56, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 57, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 58, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 59, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 60, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 61, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 62, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 63, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 64, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 65, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 66, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 67, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 68, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 69, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 70, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 71, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 72, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 73, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 74, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 75, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 76, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 77, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 78, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 79, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 80, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 81, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 82, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 83, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 84, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 85, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 86, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 87, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 88, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 89, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 90, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 91, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 92, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 93, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 94, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 95, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 96, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 97, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 98, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 99, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 100, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 101, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 102, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 103, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 104, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 105, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 106, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 107, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 108, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 109, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 110, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 111, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 112, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 113, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 114, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 115, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 116, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 117, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 118, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 119, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 120, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 121, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 122, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 123, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 124, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 125, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 126, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 127, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 128, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 129, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 130, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 131, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 132, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 133, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 134, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 135, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 136, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 137, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 138, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 139, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 140, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 141, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 142, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 143, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 144, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 145, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 20578, Frame: 146, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 0, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 1, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 2, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 3, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 4, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 5, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 6, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 7, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 8, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 9, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 10, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 11, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 12, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 13, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 14, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 15, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 16, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 17, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 18, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 19, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 20, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 21, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 22, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 23, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 24, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 25, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 26, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 27, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 28, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 29, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 30, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 31, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 32, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 33, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 34, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 35, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 36, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 37, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 38, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 39, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 40, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 41, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 42, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 43, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 44, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 45, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 46, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 47, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 48, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 49, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 50, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 51, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 52, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 53, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 54, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 55, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 56, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 57, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 58, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 59, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 60, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 61, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 62, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 63, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 64, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 65, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 66, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 67, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 68, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 69, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 70, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 71, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 72, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 73, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 74, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 451442, Frame: 75, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# ...
# Name: 759493, Frame: 23, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 24, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 25, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 26, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 27, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 28, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 29, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 30, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 31, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 32, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 33, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 34, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 35, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 36, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 37, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 38, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 39, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 40, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 41, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 42, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 43, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 44, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 45, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 46, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 47, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 48, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 49, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 50, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 51, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 52, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 53, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 54, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 55, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 56, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 57, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 58, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 59, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 60, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 61, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 62, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 63, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 64, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 65, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 66, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 67, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 68, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 69, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 70, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 71, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 72, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 73, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 74, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 75, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 76, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 77, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 78, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 79, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 80, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 81, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 82, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 83, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 84, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 85, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 86, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 87, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 88, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 89, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 90, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 91, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 92, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 93, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 94, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 95, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 96, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 97, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 98, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 99, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 100, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 101, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 102, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 103, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 104, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 105, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 106, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 107, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 108, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 109, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 110, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 111, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 112, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 113, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 114, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 115, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 116, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 117, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 118, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 119, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 120, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 121, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 122, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 123, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 124, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 125, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 126, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 127, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 128, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 129, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 130, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 131, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 132, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 133, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 134, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 135, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 136, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 137, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 138, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 139, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 140, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 141, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 142, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 143, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 144, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 145, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 146, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 147, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 148, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 149, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 150, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 151, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 152, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 153, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 154, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 155, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 156, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 157, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 158, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 159, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 160, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 161, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 162, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 163, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 164, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 165, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 166, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 167, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 168, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 169, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 170, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 171, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 172, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 173, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 759493, Frame: 174, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 0, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 1, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 2, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 3, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 4, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 5, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 6, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 7, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 8, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 9, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 10, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 11, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 12, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 13, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 14, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 15, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 16, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 17, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 18, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 19, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 20, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 21, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 22, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 23, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 24, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 25, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 26, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 27, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 28, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 29, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 30, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 31, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 32, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 33, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 34, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 35, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 36, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 37, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 38, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 39, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 40, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 41, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 42, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 43, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 44, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 45, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 46, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 47, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 48, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 49, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 50, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 51, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 52, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 53, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 54, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 55, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 56, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 57, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 58, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)
# Name: 140596, Frame: 59, Feature dim: [(3, 32), (3, 64)], Label dim: (58,)

# %%
# Some files have multiple label sets, will probably be fixed/explained in the next session (most likely the ones with multiple annotators)
special_count = {}
for file_name, label_dict in all_audio_file_labels.items():
    special = 0
    for label_name, label in label_dict.items():
        if label.shape[1] != 1:
            special = label.shape[1]
    if special:
        try:
            special_count[special] += 1
        except KeyError:
            special_count[special] = 1

    special = 0

for n_label_sets, count in special_count.items():
    print(f"Number of files with {n_label_sets} label sets: {count}")
# Already fixed now in the dataset class
# Out:
# Number of files with 2 label sets: 642
# Number of files with 3 label sets: 6
