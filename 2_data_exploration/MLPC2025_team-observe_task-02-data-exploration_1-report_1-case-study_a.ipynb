# %% [markdown]
# # MLPC 2025 Task 2: Data Exploration

# %% [markdown]
# ## 1 Report - Task 1: Case Study
#
# **Set up the project**:
# - download the data set `MLPC2025_dataset.zip` from Moodle into your working directory (`WORKING_DIR`)
# - unzip the folder
# - your project structure should look like this:
#
# ```
# MLPC2025_data_exploration/                 <---- start your terminal, powershell, etc. here or navigate to this folder (e.g., with `cd`)
# ├── MLPC2025_dataset/
# |   ├── audio/
# |   ├── audio_features/
# |   ├──── annotations.csv
# |   ├──── annotations_text_embeddings.npz
# |   ├──── metadata.csv
# |   ├──── metadata_keywords_embeddings.npz
# |   ├──── metadata_title_embeddings.npz
# |   └──── README.md
# └── MLPC2025_team-observe_task-02-data-exploration_1-report_1-case-study.ipynb      <---- run this notebook
# ```
#
# **Run the cell below** to check your setup.

# %%
import os
import math

# if you've setup your environment, importing these libraries should not throw an error
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt

from IPython.display import Audio

PATH_TO_DATASET = './MLPC2025_dataset'
#
assert os.path.exists(PATH_TO_DATASET), "The dataset folder 'MLPC2025_dataset' does not exist; download the data set and extract its content."
assert os.path.exists(os.path.join(PATH_TO_DATASET, 'audio')), "The folder 'MLPC2025_dataset/audio' does not exist."
assert os.path.exists(os.path.join(PATH_TO_DATASET, 'audio_features')), "The folder 'MLPC2025_dataset/audio_featues' does not exist."
#
assert os.path.exists(os.path.join(PATH_TO_DATASET, 'annotations.csv')), "The file 'MLPC2025_dataset/annotations.csv' does not exist."
assert os.path.exists(os.path.join(PATH_TO_DATASET, 'metadata.csv')), "The file 'MLPC2025_dataset/metadata.csv' does not exist."
#
assert os.path.exists(os.path.join(PATH_TO_DATASET, 'annotations_text_embeddings.npz')), "The file 'MLPC2025_dataset/annotations_text_embeddings.npz' does not exist."
assert os.path.exists(os.path.join(PATH_TO_DATASET, 'metadata_keywords_embeddings.npz')), "The file 'MLPC2025_dataset/metadata_keywords_embeddings.npz' does not exist."
assert os.path.exists(os.path.join(PATH_TO_DATASET, 'metadata_title_embeddings.npz')), "The file 'MLPC2025_dataset/metadata_title_embeddings.npz' does not exist."
#

# %% [markdown]
# ## Python Packages used
#
# - [Pandas](https://pandas.pydata.org/docs/) for dealing with tabular data
# - [Numpy](https://numpy.org/doc/stable/) for features
# - [Matplotlib](https://matplotlib.org/stable/users/index.html) for plotting
# - [scikit-learn](https://scikit-learn.org/stable/user_guide.html) for Machine Learning

# %% [markdown]
# # Data Set (complete)
#
# ```
# MLPC2025_Dataset/
# ├── audio/
# │   ├── 14.mp3
# │   ├── 156.mp3
# │   ├── ...
# │   ├── 790282.mp3
# |   └── 790542.mp3
# ├── audio_features/
# │   ├── 14.npz
# │   ├── 156.npz
# │   ├── ...
# │   ├── 790282.npz
# |   └── 790542.npz
# ├──── annotations.csv
# ├──── annotations_text_embeddings.npz
# ├──── metadata.csv
# ├──── metadata_keywords_embeddings.npz
# ├──── metadata_title_embeddings.npz
# └──── README.md
# ```

# %% [markdown]
# # Metadata
#
# - `metadata.csv` contains metadata information about each file
#
# # Annotations
#
# - `annotations.csv` contains the text annotations an their regions

# %% [markdown]
# ## Loading the Metadata
#
# - use `pd.read_csv(os.path.join(PATH_TO_DATASET, "metadata.csv"))` to load the file and store the result into variable `df_metadata`

# %%
print("********************************************************************************")
print("*** df_metadata ****************************************************************")
print("********************************************************************************")
df_metadata = pd.read_csv(os.path.join(PATH_TO_DATASET, "metadata.csv"))
df_metadata.info(verbose=False)
print("********************************************************************************")
##  Shape of Data Frame
print("DataFrame shape: \t", df_metadata.shape)
print("DataFrame rows: \t", len(df_metadata.index))
print("DataFrame columns: \t", len(df_metadata.columns))
print("DataFrame column names: \n", df_metadata.columns.to_list())
print(df_metadata.axes)
print("********************************************************************************")
#print(df_metadata)

# set index to filename
#df_metadata.set_index("filename", inplace=True)
#df_metadata[["keywords", "manufacturer", "description"]].head(n=4)
# Out:
# ********************************************************************************
# *** df_metadata ****************************************************************
# ********************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9026 entries, 0 to 9025
# Columns: 12 entries, filename to end_time_s
# dtypes: float64(2), int64(2), object(8)
# memory usage: 846.3+ KB
# ********************************************************************************
# DataFrame shape: 	 (9026, 12)
# DataFrame rows: 	 9026
# DataFrame columns: 	 12
# DataFrame column names:
#  ['filename', 'keywords', 'freesound_id', 'sound_link', 'manufacturer', 'license', 'title', 'description', 'num_downloads', 'geotag', 'start_time_s', 'end_time_s']
# [RangeIndex(start=0, stop=9026, step=1), Index(['filename', 'keywords', 'freesound_id', 'sound_link', 'manufacturer',
#        'license', 'title', 'description', 'num_downloads', 'geotag',
#        'start_time_s', 'end_time_s'],
#       dtype='object')]
# ********************************************************************************

# %% [markdown]
# ### Prepare Manufacturer-Count

# %%
sepa = " "
df_metadata_index_list = []

df_metadata["Manufacturer-List"] = df_metadata["manufacturer"].str.split(sepa).array
df_metadata["Manufacturer-Count"] = df_metadata["Manufacturer-List"].size

for i, row in df_metadata.iterrows() :
    df_metadata_index_list.append(i)
    df_metadata.loc[i, "Manufacturer-Count"] = len(row["Manufacturer-List"])

print("DataFrame shape: \t", df_metadata.shape)

df_metadata[["filename", "keywords", "manufacturer", "description", "Manufacturer-List", "Manufacturer-Count"]].head(n=4)
# Out:
# DataFrame shape: 	 (9026, 14)
#      filename                                           keywords  \
# 0  617030.mp3  atmosphere, general-noise, suburban, ambiance,...
# 1  637408.mp3                jackhammer, construction, reflected
# 2  615545.mp3  river-side, field-recording, bell, fields, vil...
# 3  410867.mp3  sports-crowd, applause, crowd, crowd-cheer, Ad...
#
#       manufacturer                                        description  \
# 0       klankbeeld  Night in a suburban city.  All sounds far. Tra...
# 1            kyles  construction jackhammer reflected5\n\nrecorded...
# 2       klankbeeld  Four differed church bells tell it is 7 o’cloc...
# 3  NobodyYouKnowOf  Crowd making some noise at a SANFL Aussie rule...
#
#    Manufacturer-List  Manufacturer-Count
# 0       [klankbeeld]                   1
# 1            [kyles]                   1
# 2       [klankbeeld]                   1
# 3  [NobodyYouKnowOf]                   1

# %% [markdown]
# ## Loading the Metadata-Title-Embeddings
#
# - use `np.load(os.path.join(PATH_TO_DATASET, "metadata_title_embeddings.npz"))` to load the file and append the result into variable `df_metadata_title`

# %%
metadata_title = np.load(os.path.join(PATH_TO_DATASET, "metadata_title_embeddings.npz"))
metadata_title_embeddings = metadata_title["embeddings"]

print("Metadata Title Embeddings: ", metadata_title.values)
print("Metadata Title Embeddings: ", metadata_title_embeddings.shape, " / ", metadata_title_embeddings.dtype)

df_metadata_title = df_metadata.join(pd.DataFrame(metadata_title_embeddings), how="left", validate="1:1", rsuffix="_title")

print("df_metadata_title.shape: \t", df_metadata_title.shape)
# Out:
# Metadata Title Embeddings:  <bound method NpzFile.values of NpzFile './MLPC2025_dataset\\metadata_title_embeddings.npz' with keys: embeddings>
# Metadata Title Embeddings:  (9026, 1024)  /  float32
# df_metadata_title.shape: 	 (9026, 1038)

# %% [markdown]
# ## Loading the Metadata-Keywords-Embeddings
#
# - use `np.load(os.path.join(PATH_TO_DATASET, "metadata_keywords_embeddings.npz"))` to load the file and append the result into variable `df_metadata_title_keywords`

# %%
metadata_keywords = np.load(os.path.join(PATH_TO_DATASET, "metadata_keywords_embeddings.npz"))
metadata_keywords_embeddings = metadata_keywords["embeddings"]

print("Metadata Keywords Embeddings: ", metadata_keywords.values)
print("Metadata Keywords Embeddings: ", metadata_keywords_embeddings.shape, " / ", metadata_keywords_embeddings.dtype)

df_metadata_title_keywords = df_metadata_title.join(pd.DataFrame(metadata_keywords_embeddings), how="left", validate="1:1", rsuffix="_keywords")

print("df_metadata_title_keywords.shape: \t", df_metadata_title_keywords.shape)
# Out:
# Metadata Keywords Embeddings:  <bound method NpzFile.values of NpzFile './MLPC2025_dataset\\metadata_keywords_embeddings.npz' with keys: embeddings>
# Metadata Keywords Embeddings:  (9026, 1024)  /  float32
# df_metadata_title_keywords.shape: 	 (9026, 2062)

# %% [markdown]
# ## Loading the Annotations
#
# - use `pd.read_csv(os.path.join(PATH_TO_DATASET, "annotations.csv"))` to load the file and store the result into variable `df_annotations`

# %%
print("********************************************************************************")
print("*** df_annotations *************************************************************")
print("********************************************************************************")
df_annotations = pd.read_csv(os.path.join(PATH_TO_DATASET, "annotations.csv"))
df_annotations.info(verbose=False)
print("********************************************************************************")
##  Shape of Data Frame
print("DataFrame shape: \t", df_annotations.shape)
print("DataFrame rows: \t", len(df_annotations.index))
print("DataFrame columns: \t", len(df_annotations.columns))
print("DataFrame column names: \n", df_annotations.columns.to_list())
print(df_annotations.axes)
print("********************************************************************************")
#print(df_annotations)

# set index to filename
#df_annotations.set_index("filename", inplace=True)
#df_annotations[["task_id", "annotator", "text", "onset", "offset", "filename_unsafe"]].head(n=4)
# Out:
# ********************************************************************************
# *** df_annotations *************************************************************
# ********************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35826 entries, 0 to 35825
# Columns: 7 entries, task_id to filename_unsafe
# dtypes: float64(2), int64(1), object(4)
# memory usage: 1.9+ MB
# ********************************************************************************
# DataFrame shape: 	 (35826, 7)
# DataFrame rows: 	 35826
# DataFrame columns: 	 7
# DataFrame column names:
#  ['task_id', 'filename', 'annotator', 'text', 'onset', 'offset', 'filename_unsafe']
# [RangeIndex(start=0, stop=35826, step=1), Index(['task_id', 'filename', 'annotator', 'text', 'onset', 'offset',
#        'filename_unsafe'],
#       dtype='object')]
# ********************************************************************************

# %% [markdown]
# ## Loading the Annotations-Text-Embeddings
#
# - use `np.load(os.path.join(PATH_TO_DATASET, "annotations_text_embeddings.npz"))` to load the file and append the result into variable `df_annotations_text`

# %%
annotations_text = np.load(os.path.join(PATH_TO_DATASET, "annotations_text_embeddings.npz"))
annotations_text_embeddings = annotations_text["embeddings"]

print("Annotations Text Embeddings: ", annotations_text.values)
print("Annotations Text Embeddings: ", annotations_text_embeddings.shape, " / ", annotations_text_embeddings.dtype)

df_annotations_text = df_annotations.join(pd.DataFrame(annotations_text_embeddings), how="left", validate="1:1", rsuffix="_text")

print("df_annotations_text.shape: \t", df_annotations_text.shape)
# Out:
# Annotations Text Embeddings:  <bound method NpzFile.values of NpzFile './MLPC2025_dataset\\annotations_text_embeddings.npz' with keys: embeddings>
# Annotations Text Embeddings:  (35826, 1024)  /  float32
# df_annotations_text.shape: 	 (35826, 1031)

# %% [markdown]
# ## Task 1. Case Study
# ### (a) Identify similarities or differences between temporal and textual annotations from different annotators.

# %%
df_metadata_manu_count = df_metadata_title_keywords.loc[2 <= df_metadata_title_keywords['Manufacturer-Count'], :]

print("df_metadata_manu_count.shape: \t", df_metadata_manu_count.shape)
# Out:
# df_metadata_manu_count.shape: 	 (149, 2062)

# %%
files_with_multiple_annotators = df_annotations.groupby('filename')['annotator'].nunique()
files_with_multiple_annotators = files_with_multiple_annotators[files_with_multiple_annotators > 1].index.tolist()
print("files_with_multiple_annotators = \t", len(files_with_multiple_annotators))
# Out:
# files_with_multiple_annotators = 	 731

# %%
annotations_for_files_with_multiple_annotators = df_annotations[df_annotations['filename'].isin(files_with_multiple_annotators)]
annotations_for_files_with_multiple_annotators = annotations_for_files_with_multiple_annotators.groupby(['filename', 'annotator']).agg(lambda x: list(x)).reset_index()
print("annotations_for_files_with_multiple_annotators = \t", annotations_for_files_with_multiple_annotators.shape)
# Out:
# annotations_for_files_with_multiple_annotators = 	 (1468, 7)

# %%
annotations_for_files_with_multiple_annotators.head()

for filename in annotations_for_files_with_multiple_annotators['filename'].unique():
    if len(
            annotations_for_files_with_multiple_annotators[annotations_for_files_with_multiple_annotators['filename'] == filename]
    ) != 2:
        print(len(annotations_for_files_with_multiple_annotators[annotations_for_files_with_multiple_annotators['filename'] == filename]),
            " / ", filename
        )
# Out:
# 3  /  352781.mp3
# 3  /  407115.mp3
# 3  /  424366.mp3
# 3  /  515081.mp3
# 3  /  535624.mp3
# 3  /  582364.mp3

# %%
comparison_dict = {}

for filename in annotations_for_files_with_multiple_annotators['filename'].unique():

    comparison_dict[filename] = {'metadata_embedding': None, 'annotation_embeddings': {}}

    # Get metadata embedding
    metadata_idx = df_metadata[df_metadata['filename'] == filename].index[0]
    #metadata_embedding = 0.5 * (metadata_keywords_embeddings[metadata_idx] + metadata_title_embeddings[metadata_idx])
    #metadata_embedding = metadata_keywords_embeddings[metadata_idx]
    metadata_embedding = metadata_title_embeddings[metadata_idx]

    comparison_dict[filename]['metadata_embedding'] = metadata_embedding

    # annotations specific to the file
    file_annotations = annotations_for_files_with_multiple_annotators[annotations_for_files_with_multiple_annotators['filename'] == filename]

    for annotator in file_annotations['annotator'].unique():
        annotation_indices = df_annotations[df_annotations['filename'] == filename]
        annotation_indices = annotation_indices[annotation_indices['annotator'] == annotator].index.tolist()

        # Get the text embeddings for the annotations
        annotation_embeddings = []
        for idx in annotation_indices:
            annotation_embeddings.append(annotations_text_embeddings[idx])
        annotation_embeddings = np.array(annotation_embeddings)

        # Average the embeddings for the annotator
        annotation_embeddings = np.mean(annotation_embeddings, axis=0)

        comparison_dict[filename]['annotation_embeddings'][annotator] = annotation_embeddings

# %%
for filename, embeddings in comparison_dict.items():
    print(f"Filename: {filename}")
    print(f"Metadata embedding: {embeddings['metadata_embedding'].shape}")
    for annotator, embedding in embeddings['annotation_embeddings'].items():
        print(f"Annotator: {annotator}, Embedding shape: {embedding.shape}")
    print()
# Out:
# Filename: 102431.mp3
# Metadata embedding: (1024,)
# Annotator: 28251014400027049985537852315625094069312034433417461412837429504269879097216, Embedding shape: (1024,)
# Annotator: 75058291103840756873316169650564417843042967235442422525023433266794403941324, Embedding shape: (1024,)
#
# Filename: 102744.mp3
# Metadata embedding: (1024,)
# Annotator: 114557974701560722122174406796999155076467177343665937064846969792916214273411, Embedding shape: (1024,)
# Annotator: 94679287248510806505619816087719112608619861927317400417074958422719126377505, Embedding shape: (1024,)
#
# Filename: 106035.mp3
# Metadata embedding: (1024,)
# Annotator: 38166745052496887069994378107692975296585346461051494344180693789505987975216, Embedding shape: (1024,)
# Annotator: 94178141180527890006743668970552987086187462530603562339532712111783945872368, Embedding shape: (1024,)
#
# Filename: 106969.mp3
# Metadata embedding: (1024,)
# Annotator: 101991025053897854105013557125922578872450281370015031334211021108802790545384, Embedding shape: (1024,)
# Annotator: 16645546140722306861957385955702985749448124934040871229453560983102139466669, Embedding shape: (1024,)
#
# Filename: 106979.mp3
# Metadata embedding: (1024,)
# Annotator: 1576945196264367997531683002970449852988932779053679342197484577924850532788, Embedding shape: (1024,)
# Annotator: 49646555831625257015917138948745571881455758767163420374774183779692744338090, Embedding shape: (1024,)
#
# Filename: 108514.mp3
# Metadata embedding: (1024,)
# Annotator: 17832414951333949329596581412838291770159458393717147907924429182407858848395, Embedding shape: (1024,)
# Annotator: 20139129409472599032214816947462376584986607026718595495688198768806884550414, Embedding shape: (1024,)
#
# Filename: 110921.mp3
# Metadata embedding: (1024,)
# Annotator: 4359066763754207879307315092981131937825125070899655014386217856277975547733, Embedding shape: (1024,)
# Annotator: 61159284090785319222947889403031956523974925692866851470271732580739070400057, Embedding shape: (1024,)
#
# Filename: 111059.mp3
# Metadata embedding: (1024,)
# Annotator: 37354286634043723116058383740855729941019794941266091207799662530452573074208, Embedding shape: (1024,)
# Annotator: 58864092964652614671996668460845143199712161241153187413867581031635218825787, Embedding shape: (1024,)
#
# Filename: 113327.mp3
# Metadata embedding: (1024,)
# Annotator: 64561226020994896301818750922770630849961337120757782389033140156511501318845, Embedding shape: (1024,)
# Annotator: 90175366125622214536158275984204973213956016267147912347697205194879952276970, Embedding shape: (1024,)
#
# Filename: 113355.mp3
# Metadata embedding: (1024,)
# Annotator: 20078125797336961040030171255780273211544536169955386466869632633165496989903, Embedding shape: (1024,)
# Annotator: 31236508914760797848576773117080154500702963929416614984827784808599065113728, Embedding shape: (1024,)
#
# Filename: 113356.mp3
# Metadata embedding: (1024,)
# Annotator: 46121470561536803163280701579473790907008878615498467212527765029594050618063, Embedding shape: (1024,)
# Annotator: 97408140230628903907109109301849375849414026787115715155173749724926085470188, Embedding shape: (1024,)
#
# Filename: 114286.mp3
# Metadata embedding: (1024,)
# Annotator: 62355735792070369579481490774570832616665152146396382296147532179774877789611, Embedding shape: (1024,)
# Annotator: 89605346468130623187845926321735893498068174586262008506078141839731327750098, Embedding shape: (1024,)
#
# Filename: 116791.mp3
# Metadata embedding: (1024,)
# Annotator: 35149575729600094469332859178599505486187445313127624875957623647899891868542, Embedding shape: (1024,)
# Annotator: 49170229913260714455264004892366186828043132192653820001894273174821873841364, Embedding shape: (1024,)
#
# Filename: 117611.mp3
# Metadata embedding: (1024,)
# Annotator: 57835086208742693355557312559196303821474911200770380653032223797734258614886, Embedding shape: (1024,)
# Annotator: 84704702810492203570508455757276662194775685610231578309011132791728316253685, Embedding shape: (1024,)
#
# Filename: 118341.mp3
# Metadata embedding: (1024,)
# Annotator: 29231542252815636014158629708776025252021989914958927030375614180068233842454, Embedding shape: (1024,)
# Annotator: 41351022583365499593297677603159211181347474768481975112691716409556442907004, Embedding shape: (1024,)
#
# Filename: 118728.mp3
# Metadata embedding: (1024,)
# Annotator: 411636573135802475484269253664194870658670826351810573916181360144468290346, Embedding shape: (1024,)
# Annotator: 89707952857497017702801712624756956146923507297260780078256408537217781166243, Embedding shape: (1024,)
#
# Filename: 119173.mp3
# Metadata embedding: (1024,)
# Annotator: 81050775002249204442988358298812104278711906928185136365317282280534071747730, Embedding shape: (1024,)
# Annotator: 84704702810492203570508455757276662194775685610231578309011132791728316253685, Embedding shape: (1024,)
#
# Filename: 120106.mp3
# Metadata embedding: (1024,)
# Annotator: 20078125797336961040030171255780273211544536169955386466869632633165496989903, Embedding shape: (1024,)
# Annotator: 34599952449478303339170893443367097151977584687362698788013603968787498535020, Embedding shape: (1024,)
#
# Filename: 121364.mp3
# Metadata embedding: (1024,)
# Annotator: 3329037780918753664896354518949133980941803646292432223728461889854282789379, Embedding shape: (1024,)
# Annotator: 92634347167582054208909188910401982926370030971127071443490525841828250349112, Embedding shape: (1024,)
#
# Filename: 121532.mp3
# Metadata embedding: (1024,)
# Annotator: 100425450317906496390895388623230530869228496891340467419161733048453242108576, Embedding shape: (1024,)
# Annotator: 110146097304690711764984839687508731980429626769134693943414351569723887294841, Embedding shape: (1024,)
#
# Filename: 122956.mp3
# Metadata embedding: (1024,)
# Annotator: 100085476285274256355828104148824375899078643541741339916509444476406988392584, Embedding shape: (1024,)
# Annotator: 94057971961546359846229431462387685271883384943446523429356802373347207481651, Embedding shape: (1024,)
#
# Filename: 122978.mp3
# Metadata embedding: (1024,)
# Annotator: 102834162874743039972126867430893976507845628340201871147467671756946315453713, Embedding shape: (1024,)
# Annotator: 104924767736343993719500018610793636516781222351726089102184951313702700817380, Embedding shape: (1024,)
#
# Filename: 124674.mp3
# Metadata embedding: (1024,)
# Annotator: 106415021946906009927283955069079778505987800814508135830007480677667177775892, Embedding shape: (1024,)
# Annotator: 88735560925722981485197011450981396988153846085945372478378990186355410248985, Embedding shape: (1024,)
#
# Filename: 125559.mp3
# Metadata embedding: (1024,)
# Annotator: 36523652429724867832162805348164187693953586177548906684789381551511497770389, Embedding shape: (1024,)
# Annotator: 94178141180527890006743668970552987086187462530603562339532712111783945872368, Embedding shape: (1024,)
#
# Filename: 125652.mp3
# Metadata embedding: (1024,)
# Annotator: 67620845542485631793854021399703221612007486192562720294997218848118588966413, Embedding shape: (1024,)
# Annotator: 75058291103840756873316169650564417843042967235442422525023433266794403941324, Embedding shape: (1024,)
#
# Filename: 127345.mp3
# Metadata embedding: (1024,)
# Annotator: 104756685299042146837482008251463456417662964537684177690962768783435787306510, Embedding shape: (1024,)
# Annotator: 20078125797336961040030171255780273211544536169955386466869632633165496989903, Embedding shape: (1024,)
#
# Filename: 127606.mp3
# Metadata embedding: (1024,)
# Annotator: 106911886166157606552394347668082919414947693521457064598390687700142985287061, Embedding shape: (1024,)
# Annotator: 94057971961546359846229431462387685271883384943446523429356802373347207481651, Embedding shape: (1024,)
#
# Filename: 130473.mp3
# Metadata embedding: (1024,)
# Annotator: 110171912972381667310173820221062533999869813452104281316231006518167932661960, Embedding shape: (1024,)
# Annotator: 84704702810492203570508455757276662194775685610231578309011132791728316253685, Embedding shape: (1024,)
#
# Filename: 132076.mp3
# Metadata embedding: (1024,)
# Annotator: 49646555831625257015917138948745571881455758767163420374774183779692744338090, Embedding shape: (1024,)
# Annotator: 52071871693074840541222807364176644469330956565548297515640298411415286315997, Embedding shape: (1024,)
#
# Filename: 134783.mp3
# Metadata embedding: (1024,)
# Annotator: 10892465509316365220502650175026973951304116600419136804347876697818021848547, Embedding shape: (1024,)
# Annotator: 31399784615888520779712022413793685228274804251028833560156799174446262728298, Embedding shape: (1024,)
#
# Filename: 136599.mp3
# Metadata embedding: (1024,)
# Annotator: 101926091523301466166793746484308928560448816217364607449429659670077229469722, Embedding shape: (1024,)
# Annotator: 20078125797336961040030171255780273211544536169955386466869632633165496989903, Embedding shape: (1024,)
#
# Filename: 136978.mp3
# Metadata embedding: (1024,)
# Annotator: 103956490265872391515072801731663228214095801469532284439067643074879171129893, Embedding shape: (1024,)
# Annotator: 104756685299042146837482008251463456417662964537684177690962768783435787306510, Embedding shape: (1024,)
#
# Filename: 138014.mp3
# Metadata embedding: (1024,)
# Annotator: 111470609057027258204760356772901372667093782461401366104731370689359417330241, Embedding shape: (1024,)
# Annotator: 115270002470903402094009748375419749823454542819649441575263009926782328625557, Embedding shape: (1024,)
#
# Filename: 139092.mp3
# Metadata embedding: (1024,)
# Annotator: 10086764085507696045382527086830681912527682927599423915046870876145676096363, Embedding shape: (1024,)
# Annotator: 92310170377496867392989019747425810144947610507206644637008076034878071100422, Embedding shape: (1024,)
#
# Filename: 139958.mp3
# Metadata embedding: (1024,)
# Annotator: 68946096525553517837301244669921520452233607944530604744485124623740136078067, Embedding shape: (1024,)
# Annotator: 84704702810492203570508455757276662194775685610231578309011132791728316253685, Embedding shape: (1024,)
#
# Filename: 140581.mp3
# Metadata embedding: (1024,)
# Annotator: 104756685299042146837482008251463456417662964537684177690962768783435787306510, Embedding shape: (1024,)
# Annotator: 59016308817356405683955492143736755013182644487918792344278684114186450280309, Embedding shape: (1024,)
#
# Filename: 141704.mp3
# Metadata embedding: (1024,)
# Annotator: 5200118597633422011154995287823972042985788664370946857401795431077585445710, Embedding shape: (1024,)
# Annotator: 79870316315349615302327941860366026996801340811276116342195412772582394036186, Embedding shape: (1024,)
#
# Filename: 143645.mp3
# Metadata embedding: (1024,)
# Annotator: 19274652190551184005429103272420013307837648464337096715513837103873370045363, Embedding shape: (1024,)
# Annotator: 79596993505278277732257455477611932911200984635046686126048185036433824185401, Embedding shape: (1024,)
#
# Filename: 143964.mp3
# Metadata embedding: (1024,)
# Annotator: 113160997761811326360045523441018522085460579083321546928079897819053774917750, Embedding shape: (1024,)
# Annotator: 94679287248510806505619816087719112608619861927317400417074958422719126377505, Embedding shape: (1024,)
#
# Filename: 144473.mp3
# Metadata embedding: (1024,)
# Annotator: 48356515686361907165258413690647379730169243794640403736946839798964540655893, Embedding shape: (1024,)
# Annotator: 62355735792070369579481490774570832616665152146396382296147532179774877789611, Embedding shape: (1024,)
#
# Filename: 146436.mp3
# Metadata embedding: (1024,)
# Annotator: 26073351235181780954515437889881027237537732239708063549963430833877522518498, Embedding shape: (1024,)
# Annotator: 38854216392157211546493442945882487577763177973096877995053855951681462737209, Embedding shape: (1024,)
#
# Filename: 147349.mp3
# Metadata embedding: (1024,)
# Annotator: 18881987009468310036938990504199375630410943184810952187948229647847943348359, Embedding shape: (1024,)
# Annotator: 69582610963371663743573649920842828901743347072739129727669537040269939692676, Embedding shape: (1024,)
#
# Filename: 148788.mp3
# Metadata embedding: (1024,)
# Annotator: 43099734658868412370465219488865636572028612578912864260375807020106181373595, Embedding shape: (1024,)
# Annotator: 59075493800294758042511046899055721009337983589516646257809703822386370686357, Embedding shape: (1024,)
#
# Filename: 151005.mp3
# Metadata embedding: (1024,)
# Annotator: 56619359705747999618666172109813882213529055490551023927926233998787623006904, Embedding shape: (1024,)
# Annotator: 79760708327668211251701507840431228309622359997994107391005449478180927357547, Embedding shape: (1024,)
#
# Filename: 151279.mp3
# Metadata embedding: (1024,)
# Annotator: 84704702810492203570508455757276662194775685610231578309011132791728316253685, Embedding shape: (1024,)
# Annotator: 94679287248510806505619816087719112608619861927317400417074958422719126377505, Embedding shape: (1024,)
#
# Filename: 154783.mp3
# Metadata embedding: (1024,)
# Annotator: 61875412005525865471274864653561951218081484628348910439107842633998022795640, Embedding shape: (1024,)
# Annotator: 82551235284309739653968008344814210311916058661833406739518790857443368745586, Embedding shape: (1024,)
#
# Filename: 157205.mp3
# Metadata embedding: (1024,)
# Annotator: 411636573135802475484269253664194870658670826351810573916181360144468290346, Embedding shape: (1024,)
# Annotator: 43619383270204614596253202146404700594767651599352547347919374143305127339985, Embedding shape: (1024,)
#
# Filename: 158518.mp3
# Metadata embedding: (1024,)
# Annotator: 90175366125622214536158275984204973213956016267147912347697205194879952276970, Embedding shape: (1024,)
# Annotator: 90675002784724645719135968568905209515724062895163968745792672428867520585552, Embedding shape: (1024,)
#
# Filename: 159328.mp3
# Metadata embedding: (1024,)
# Annotator: 104924767736343993719500018610793636516781222351726089102184951313702700817380, Embedding shape: (1024,)
# Annotator: 52774512441422001482295385443052285592026321448521831257057994761101460318087, Embedding shape: (1024,)
#
# Filename: 159437.mp3
# Metadata embedding: (1024,)
# Annotator: 46121470561536803163280701579473790907008878615498467212527765029594050618063, Embedding shape: (1024,)
# Annotator: 84704702810492203570508455757276662194775685610231578309011132791728316253685, Embedding shape: (1024,)
#
# Filename: 159747.mp3
# Metadata embedding: (1024,)
# Annotator: 36523652429724867832162805348164187693953586177548906684789381551511497770389, Embedding shape: (1024,)
# Annotator: 49170229913260714455264004892366186828043132192653820001894273174821873841364, Embedding shape: (1024,)
#
# Filename: 160158.mp3
# Metadata embedding: (1024,)
# Annotator: 6483200975886909670109160332103682737904662177103802400430437968986716776325, Embedding shape: (1024,)
# Annotator: 99262612552325878298244668181556731091295316460923843379677871092286899210298, Embedding shape: (1024,)
#
# Filename: 16043.mp3
# Metadata embedding: (1024,)
# Annotator: 115314470143541322961118539909043565361001388145309394605879917719421732048777, Embedding shape: (1024,)
# Annotator: 48356515686361907165258413690647379730169243794640403736946839798964540655893, Embedding shape: (1024,)
#
# Filename: 160769.mp3
# Metadata embedding: (1024,)
# Annotator: 106081628063691536280231067634000531661252027108748144051353658655395634963236, Embedding shape: (1024,)
# Annotator: 75728268848254724789624479527609996821348047288370431573319973208326731852787, Embedding shape: (1024,)
#
# Filename: 161883.mp3
# Metadata embedding: (1024,)
# Annotator: 211160333621508683506003156249677848092548350048907991748732990169885213900, Embedding shape: (1024,)
# Annotator: 48356515686361907165258413690647379730169243794640403736946839798964540655893, Embedding shape: (1024,)
#
# Filename: 161893.mp3
# Metadata embedding: (1024,)
# Annotator: 53464569399578635112748285231005024932866458583911680643638500048780162363058, Embedding shape: (1024,)
# Annotator: 85247544917562590207669232265369485554402586734774147097525263757340943883745, Embedding shape: (1024,)
#
# Filename: 161896.mp3
# Metadata embedding: (1024,)
# Annotator: 48862512073162945459959687714911644771559423849078488155297076023003444481518, Embedding shape: (1024,)
# Annotator: 49646555831625257015917138948745571881455758767163420374774183779692744338090, Embedding shape: (1024,)
#
# Filename: 165096.mp3
# Metadata embedding: (1024,)
# Annotator: 17732254876612142432309580940576443340936120285362258399811639278508591198091, Embedding shape: (1024,)
# Annotator: 70000394218414441453012629271724259523248988630606842362152824925662801238920, Embedding shape: (1024,)
#
# Filename: 165265.mp3
# Metadata embedding: (1024,)
# Annotator: 103956490265872391515072801731663228214095801469532284439067643074879171129893, Embedding shape: (1024,)
# Annotator: 5066749238262937777735330933221191407821243639193437054829877133545692559010, Embedding shape: (1024,)
#
# Filename: 166260.mp3
# Metadata embedding: (1024,)
# Annotator: 71097486811686361953432820519834661510859245759465082945135801795142451534977, Embedding shape: (1024,)
# Annotator: 98156558448106268043595687228862557017562074968028544225755226975716671693205, Embedding shape: (1024,)
#
# Filename: 166415.mp3
# Metadata embedding: (1024,)
# Annotator: 17147357368005475174368921112099049712396096571137169777666546062424752150465, Embedding shape: (1024,)
# Annotator: 57835086208742693355557312559196303821474911200770380653032223797734258614886, Embedding shape: (1024,)
#
# Filename: 166643.mp3
# Metadata embedding: (1024,)
# Annotator: 93599868134001612328228589435004087662012545026542699120038015220920391547280, Embedding shape: (1024,)
# Annotator: 95696213145774935200833325309498212794154824043855851991339243723578185595387, Embedding shape: (1024,)
#
# Filename: 168078.mp3
# Metadata embedding: (1024,)
# Annotator: 20546297406041413108126944669340850369236459961139398489918929227196808618116, Embedding shape: (1024,)
# Annotator: 80605857326292737220762900042017827864121171391762020790268739857277505598612, Embedding shape: (1024,)
#
# Filename: 168079.mp3
# Metadata embedding: (1024,)
# Annotator: 103899207086522017945911823197799983584796723346154550367911728736537654824996, Embedding shape: (1024,)
# Annotator: 68991112651884469867522519522057827653294389397099856072401566372288745963852, Embedding shape: (1024,)
#
# Filename: 169236.mp3
# Metadata embedding: (1024,)
# Annotator: 100535866736783074762416578262272693273342178641522928107157452689480921183558, Embedding shape: (1024,)
# Annotator: 48092315781065634262321756439375093643471482049118901031306943007864682229954, Embedding shape: (1024,)
#
# Filename: 170316.mp3
# Metadata embedding: (1024,)
# Annotator: 111470609057027258204760356772901372667093782461401366104731370689359417330241, Embedding shape: (1024,)
# Annotator: 27293262522828174203196378455450922961191459192428430236877941429640823553993, Embedding shape: (1024,)
#
# Filename: 17056.mp3
# Metadata embedding: (1024,)
# Annotator: 16645546140722306861957385955702985749448124934040871229453560983102139466669, Embedding shape: (1024,)
# Annotator: 89707952857497017702801712624756956146923507297260780078256408537217781166243, Embedding shape: (1024,)
#
# Filename: 17112.mp3
# Metadata embedding: (1024,)
# Annotator: 114697563938404661396945902701797315715132465023441131092443637938676177963693, Embedding shape: (1024,)
# Annotator: 58864092964652614671996668460845143199712161241153187413867581031635218825787, Embedding shape: (1024,)
#
# Filename: 171981.mp3
# Metadata embedding: (1024,)
# Annotator: 107028234744799091220348459516645662959327769405992789494307959224721316830599, Embedding shape: (1024,)
# Annotator: 49646555831625257015917138948745571881455758767163420374774183779692744338090, Embedding shape: (1024,)
#
# Filename: 172006.mp3
# Metadata embedding: (1024,)
# Annotator: 3317414936298431696649139783659467911597120442929652646309738187785390246124, Embedding shape: (1024,)
# Annotator: 62355735792070369579481490774570832616665152146396382296147532179774877789611, Embedding shape: (1024,)
#
# Filename: 172738.mp3
# Metadata embedding: (1024,)
# Annotator: 62883765306800336674960299070997168485387625840275185443012937071154406071377, Embedding shape: (1024,)
# Annotator: 99951303508673110346022354986967077695319350363605951137127360798071120255566, Embedding shape: (1024,)
#
# Filename: 172759.mp3
# Metadata embedding: (1024,)
# Annotator: 113160997761811326360045523441018522085460579083321546928079897819053774917750, Embedding shape: (1024,)
# Annotator: 16645546140722306861957385955702985749448124934040871229453560983102139466669, Embedding shape: (1024,)
#
# Filename: 174093.mp3
# Metadata embedding: (1024,)
# Annotator: 100085476285274256355828104148824375899078643541741339916509444476406988392584, Embedding shape: (1024,)
# Annotator: 20139129409472599032214816947462376584986607026718595495688198768806884550414, Embedding shape: (1024,)
#
# Filename: 17474.mp3
# Metadata embedding: (1024,)
# Annotator: 85069467606322681959652023504043707353468721093396593935422967892135230405738, Embedding shape: (1024,)
# Annotator: 92310170377496867392989019747425810144947610507206644637008076034878071100422, Embedding shape: (1024,)
#
# Filename: 175167.mp3
# Metadata embedding: (1024,)
# Annotator: 18934951173249346942957447943426816537870457850773795155716532942088148929592, Embedding shape: (1024,)
# Annotator: 49646555831625257015917138948745571881455758767163420374774183779692744338090, Embedding shape: (1024,)
#
# Filename: 17530.mp3
# Metadata embedding: (1024,)
# Annotator: 106911886166157606552394347668082919414947693521457064598390687700142985287061, Embedding shape: (1024,)
# Annotator: 58864092964652614671996668460845143199712161241153187413867581031635218825787, Embedding shape: (1024,)
#
# Filename: 17554.mp3
# Metadata embedding: (1024,)
# Annotator: 115270002470903402094009748375419749823454542819649441575263009926782328625557, Embedding shape: (1024,)
# Annotator: 72782441800300418808583652952484174451747915006966805944741970584276427864678, Embedding shape: (1024,)
#
# Filename: 176634.mp3
# Metadata embedding: (1024,)
# Annotator: 114557974701560722122174406796999155076467177343665937064846969792916214273411, Embedding shape: (1024,)
# Annotator: 72535930987437053286805424098123610927825507090917516236955330415207729567077, Embedding shape: (1024,)
#
# Filename: 177858.mp3
# Metadata embedding: (1024,)
# Annotator: 45450481666574546372750740813008441116285649811380379953850685538212673771047, Embedding shape: (1024,)
# Annotator: 68946096525553517837301244669921520452233607944530604744485124623740136078067, Embedding shape: (1024,)
#
# Filename: 180907.mp3
# Metadata embedding: (1024,)
# Annotator: 4359066763754207879307315092981131937825125070899655014386217856277975547733, Embedding shape: (1024,)
# Annotator: 54020089824181856487207153336286365028222400294129612266063350557662298027402, Embedding shape: (1024,)
#
# Filename: 181661.mp3
# Metadata embedding: (1024,)
# Annotator: 119725330223616336444456942983719772345304443674145662233206780789370336142, Embedding shape: (1024,)
# Annotator: 15605154902645992964794594002716931446484078225618815365150780211649211425613, Embedding shape: (1024,)
#
# Filename: 182277.mp3
# Metadata embedding: (1024,)
# Annotator: 11235025750893334987515811224901126444532282124799654216415594163534250880759, Embedding shape: (1024,)
# Annotator: 112371228566629488027497712581901251347743334869562648944080289713877118576261, Embedding shape: (1024,)
#
# Filename: 182311.mp3
# Metadata embedding: (1024,)
# Annotator: 22809020532504893503751514862976010478643970205507305673064627775825462012312, Embedding shape: (1024,)
# Annotator: 50643818889834686945333908225258808660000315937544174456086008561846245883015, Embedding shape: (1024,)
#
# Filename: 184943.mp3
# Metadata embedding: (1024,)
# Annotator: 21731403352566939458290932445848497509228486043659747918552528793263295950144, Embedding shape: (1024,)
# Annotator: 84502834521198386862034138584790973198130542413073556542036852105503584126185, Embedding shape: (1024,)
#
# Filename: 185070.mp3
# Metadata embedding: (1024,)
# Annotator: 36809060307629583041571608323731137906831252713434867750685589918375052443326, Embedding shape: (1024,)
# Annotator: 63040938136515160914966493605970340160717998482808126908963136051453726699567, Embedding shape: (1024,)
#
# Filename: 18632.mp3
# Metadata embedding: (1024,)
# Annotator: 100333236523323873635701491776437452012511734958869982328013169408686230286600, Embedding shape: (1024,)
# Annotator: 104924767736343993719500018610793636516781222351726089102184951313702700817380, Embedding shape: (1024,)
#
# Filename: 18666.mp3
# Metadata embedding: (1024,)
# Annotator: 62355735792070369579481490774570832616665152146396382296147532179774877789611, Embedding shape: (1024,)
# Annotator: 80605857326292737220762900042017827864121171391762020790268739857277505598612, Embedding shape: (1024,)
#
# Filename: 190682.mp3
# Metadata embedding: (1024,)
# Annotator: 52071871693074840541222807364176644469330956565548297515640298411415286315997, Embedding shape: (1024,)
# Annotator: 76775683235442617648596312314365421075444993654323214201706882472761894464039, Embedding shape: (1024,)
#
# Filename: 191891.mp3
# Metadata embedding: (1024,)
# Annotator: 29231542252815636014158629708776025252021989914958927030375614180068233842454, Embedding shape: (1024,)
# Annotator: 91232267130641345824439720542152630048221954781236392317252938417249988218342, Embedding shape: (1024,)
#
# Filename: 192231.mp3
# Metadata embedding: (1024,)
# Annotator: 114697563938404661396945902701797315715132465023441131092443637938676177963693, Embedding shape: (1024,)
# Annotator: 20703981260002013510120757687613666097085158808725795979350977443443209529008, Embedding shape: (1024,)
#
# Filename: 197445.mp3
# Metadata embedding: (1024,)
# Annotator: 49646555831625257015917138948745571881455758767163420374774183779692744338090, Embedding shape: (1024,)
# Annotator: 77911310470423526869801569915069488805345185766638907351266805052657283315168, Embedding shape: (1024,)
#
# Filename: 197705.mp3
# Metadata embedding: (1024,)
# Annotator: 77136153138153957648969923901745082593988972272307072898068289688617925694838, Embedding shape: (1024,)
# Annotator: 99951303508673110346022354986967077695319350363605951137127360798071120255566, Embedding shape: (1024,)
#
# Filename: 198861.mp3
# Metadata embedding: (1024,)
# Annotator: 103899207086522017945911823197799983584796723346154550367911728736537654824996, Embedding shape: (1024,)
# Annotator: 20139129409472599032214816947462376584986607026718595495688198768806884550414, Embedding shape: (1024,)
#
# Filename: 199263.mp3
# Metadata embedding: (1024,)
# Annotator: 48936834123901104397256281138823025213043854789639295501813390096740392261149, Embedding shape: (1024,)
# Annotator: 87805567961116978481346376097272673745882266162160258559762904982999259135316, Embedding shape: (1024,)
#
# Filename: 202160.mp3
# Metadata embedding: (1024,)
# Annotator: 112371228566629488027497712581901251347743334869562648944080289713877118576261, Embedding shape: (1024,)
# Annotator: 67403457891108696056353927513825894277157080037650893722622884910463124172564, Embedding shape: (1024,)
#
# Filename: 202519.mp3
# Metadata embedding: (1024,)
# Annotator: 43619383270204614596253202146404700594767651599352547347919374143305127339985, Embedding shape: (1024,)
# Annotator: 52774512441422001482295385443052285592026321448521831257057994761101460318087, Embedding shape: (1024,)
#
# Filename: 203149.mp3
# Metadata embedding: (1024,)
# Annotator: 55340340813223415328630925528458732286311395013930503995352353850108948193755, Embedding shape: (1024,)
# Annotator: 83798156097639272746679852169789049963467405372196161228635156944547831524295, Embedding shape: (1024,)
#
# Filename: 209335.mp3
# Metadata embedding: (1024,)
# Annotator: 35149575729600094469332859178599505486187445313127624875957623647899891868542, Embedding shape: (1024,)
# Annotator: 76750531339122961858065176061379410965827846316329275713358131261761147538676, Embedding shape: (1024,)
#
# Filename: 210034.mp3
# Metadata embedding: (1024,)
# Annotator: 32404435098302889223815822931975980054146626547630928606957573943180511640896, Embedding shape: (1024,)
# Annotator: 53337707496172741684125180427010811717700387520544676352570962962172231025747, Embedding shape: (1024,)
#
# Filename: 210434.mp3
# Metadata embedding: (1024,)
# Annotator: 56619359705747999618666172109813882213529055490551023927926233998787623006904, Embedding shape: (1024,)
# Annotator: 60876728514720431054208745826950898672762368558208573042890123281618456439716, Embedding shape: (1024,)
#
# Filename: 210716.mp3
# Metadata embedding: (1024,)
# Annotator: 103399390517716422509339112576285492467124639608749074471864491760058786872916, Embedding shape: (1024,)
# Annotator: 95982525545084959255470907435132318621932805516313780196993209928157276382290, Embedding shape: (1024,)
#
# Filename: 211529.mp3
# Metadata embedding: (1024,)
# Annotator: 15605154902645992964794594002716931446484078225618815365150780211649211425613, Embedding shape: (1024,)
# Annotator: 59075493800294758042511046899055721009337983589516646257809703822386370686357, Embedding shape: (1024,)
#
# Filename: 212652.mp3
# Metadata embedding: (1024,)
# Annotator: 111048520864636522776803147933682021305700259156035769445760170503327966213803, Embedding shape: (1024,)
# Annotator: 67620845542485631793854021399703221612007486192562720294997218848118588966413, Embedding shape: (1024,)
#
# Filename: 213364.mp3
# Metadata embedding: (1024,)
# Annotator: 41351022583365499593297677603159211181347474768481975112691716409556442907004, Embedding shape: (1024,)
# Annotator: 71097486811686361953432820519834661510859245759465082945135801795142451534977, Embedding shape: (1024,)
#
# Filename: 216165.mp3
# Metadata embedding: (1024,)
# Annotator: 34137430529440048266273605834078933114245760186745033373880775461025578357450, Embedding shape: (1024,)
# Annotator: 85069467606322681959652023504043707353468721093396593935422967892135230405738, Embedding shape: (1024,)
#
# Filename: 216568.mp3
# Metadata embedding: (1024,)
# Annotator: 31399784615888520779712022413793685228274804251028833560156799174446262728298, Embedding shape: (1024,)
# Annotator: 90608273471384210378430309897246109633460844457380569550940432041287909172196, Embedding shape: (1024,)
#
# Filename: 217486.mp3
# Metadata embedding: (1024,)
# Annotator: 10451152326677364783315270808967269358824994919712286362850418400631873360933, Embedding shape: (1024,)
# Annotator: 37845193262545752788102471804785396545206069541282035650539619852010864893764, Embedding shape: (1024,)
#
# Filename: 218387.mp3
# Metadata embedding: (1024,)
# Annotator: 48356515686361907165258413690647379730169243794640403736946839798964540655893, Embedding shape: (1024,)
# Annotator: 59459710353809300990538585954543625498069905337512074229555445030258347839167, Embedding shape: (1024,)
#
# Filename: 218420.mp3
# Metadata embedding: (1024,)
# Annotator: 53464569399578635112748285231005024932866458583911680643638500048780162363058, Embedding shape: (1024,)
# Annotator: 94178141180527890006743668970552987086187462530603562339532712111783945872368, Embedding shape: (1024,)
#
# Filename: 221499.mp3
# Metadata embedding: (1024,)
# Annotator: 25118360308755940542490183966488101230646242255621281746265863774856750549315, Embedding shape: (1024,)
# Annotator: 77847217993586581323367433959458744743720025207383768726551729877644719535905, Embedding shape: (1024,)
#
# Filename: 221755.mp3
# Metadata embedding: (1024,)
# Annotator: 21915322070463801198423647818762039158521682809602587103552215082550618199837, Embedding shape: (1024,)
# Annotator: 44495312724412944634163893151891912548307644244544398843526680562067585111403, Embedding shape: (1024,)
#
# Filename: 222806.mp3
# Metadata embedding: (1024,)
# Annotator: 112320368631133594079721477387743442125229558603390046426548333508340176088849, Embedding shape: (1024,)
# Annotator: 83668893003008678305118405095817913716497674204911163421851306056878320318153, Embedding shape: (1024,)
#
# Filename: 22909.mp3
# Metadata embedding: (1024,)
# Annotator: 110146097304690711764984839687508731980429626769134693943414351569723887294841, Embedding shape: (1024,)
# Annotator: 57768994188635898453585596948260823503960977043569902094673919660879916194183, Embedding shape: (1024,)
#
# Filename: 23219.mp3
# Metadata embedding: (1024,)
# Annotator: 59459710353809300990538585954543625498069905337512074229555445030258347839167, Embedding shape: (1024,)
# Annotator: 76775683235442617648596312314365421075444993654323214201706882472761894464039, Embedding shape: (1024,)
#
# Filename: 232200.mp3
# Metadata embedding: (1024,)
# Annotator: 64561226020994896301818750922770630849961337120757782389033140156511501318845, Embedding shape: (1024,)
# Annotator: 81704926497561470607782900332670626745456804024119641522698661520266964683051, Embedding shape: (1024,)
#
# Filename: 23222.mp3
# Metadata embedding: (1024,)
# Annotator: 52791938628006086357684805458892974749694017418510024490150941484388701905778, Embedding shape: (1024,)
# Annotator: 6431647378238034395317169473724521494888400320565762508794496647897274359802, Embedding shape: (1024,)
#
# Filename: 232409.mp3
# Metadata embedding: (1024,)
# Annotator: 16645546140722306861957385955702985749448124934040871229453560983102139466669, Embedding shape: (1024,)
# Annotator: 44346349317752316307531474790375206168213923240383539722619977044200122702563, Embedding shape: (1024,)
#
# Filename: 233312.mp3
# Metadata embedding: (1024,)
# Annotator: 18625123121936993551823815191902498232842322537608721293487798493260616709459, Embedding shape: (1024,)
# Annotator: 28251014400027049985537852315625094069312034433417461412837429504269879097216, Embedding shape: (1024,)
#
# Filename: 233583.mp3
# Metadata embedding: (1024,)
# Annotator: 101926091523301466166793746484308928560448816217364607449429659670077229469722, Embedding shape: (1024,)
# Annotator: 104756685299042146837482008251463456417662964537684177690962768783435787306510, Embedding shape: (1024,)
#
# Filename: 23387.mp3
# Metadata embedding: (1024,)
# Annotator: 11235025750893334987515811224901126444532282124799654216415594163534250880759, Embedding shape: (1024,)
# Annotator: 83668893003008678305118405095817913716497674204911163421851306056878320318153, Embedding shape: (1024,)
#
# Filename: 234145.mp3
# Metadata embedding: (1024,)
# Annotator: 17732254876612142432309580940576443340936120285362258399811639278508591198091, Embedding shape: (1024,)
# Annotator: 53464569399578635112748285231005024932866458583911680643638500048780162363058, Embedding shape: (1024,)
#
# Filename: 234628.mp3
# Metadata embedding: (1024,)
# Annotator: 11168209049119697785284156939259715723838323298012206801210080796232413857942, Embedding shape: (1024,)
# Annotator: 42832531423519554457274244571212110587186532342101904762485997123882633298080, Embedding shape: (1024,)
#
# Filename: 234932.mp3
# Metadata embedding: (1024,)
# Annotator: 54020089824181856487207153336286365028222400294129612266063350557662298027402, Embedding shape: (1024,)
# Annotator: 84704702810492203570508455757276662194775685610231578309011132791728316253685, Embedding shape: (1024,)
#
# Filename: 238638.mp3
# Metadata embedding: (1024,)
# Annotator: 38166745052496887069994378107692975296585346461051494344180693789505987975216, Embedding shape: (1024,)
# Annotator: 84704702810492203570508455757276662194775685610231578309011132791728316253685, Embedding shape: (1024,)
#
# Filename: 24205.mp3
# Metadata embedding: (1024,)
# Annotator: 114697563938404661396945902701797315715132465023441131092443637938676177963693, Embedding shape: (1024,)
# Annotator: 278073779453504337670053734016859883188739182188708052954748456899916808024, Embedding shape: (1024,)
#
# Filename: 242861.mp3
# Metadata embedding: (1024,)
# Annotator: 107800611771339853201519538881550028468094657305575439519837954251757479908717, Embedding shape: (1024,)
# Annotator: 70000394218414441453012629271724259523248988630606842362152824925662801238920, Embedding shape: (1024,)
#
# Filename: 243486.mp3
# Metadata embedding: (1024,)
# Annotator: 3317414936298431696649139783659467911597120442929652646309738187785390246124, Embedding shape: (1024,)
# Annotator: 64368141419366353231248153947800598854301986961326580320203678560534249792401, Embedding shape: (1024,)
#
# Filename: 243582.mp3
# Metadata embedding: (1024,)
# Annotator: 100891559371388235637745855192938536395981325266457579975705426705723691979292, Embedding shape: (1024,)
# Annotator: 5205755124099136934704458531175815755122499213604591541306002701912143415123, Embedding shape: (1024,)
#
# Filename: 243716.mp3
# Metadata embedding: (1024,)
# Annotator: 77911310470423526869801569915069488805345185766638907351266805052657283315168, Embedding shape: (1024,)
# Annotator: 87805567961116978481346376097272673745882266162160258559762904982999259135316, Embedding shape: (1024,)
#
# Filename: 248262.mp3
# Metadata embedding: (1024,)
# Annotator: 42007950479082425063737052915855176969224440032882617579173734264596512642925, Embedding shape: (1024,)
# Annotator: 71097486811686361953432820519834661510859245759465082945135801795142451534977, Embedding shape: (1024,)
#
# Filename: 248322.mp3
# Metadata embedding: (1024,)
# Annotator: 57635733311314748899556841402932082724073216862549780021094218572796681062404, Embedding shape: (1024,)
# Annotator: 98156558448106268043595687228862557017562074968028544225755226975716671693205, Embedding shape: (1024,)
#
# Filename: 250861.mp3
# Metadata embedding: (1024,)
# Annotator: 44346349317752316307531474790375206168213923240383539722619977044200122702563, Embedding shape: (1024,)
# Annotator: 77303111649669607137830086299452712637458216510998727246511180629500664192180, Embedding shape: (1024,)
#
# Filename: 256988.mp3
# Metadata embedding: (1024,)
# Annotator: 115270002470903402094009748375419749823454542819649441575263009926782328625557, Embedding shape: (1024,)
# Annotator: 71714977193455752457308303974933244667376894328297014884399140380547807112516, Embedding shape: (1024,)
#
# Filename: 257509.mp3
# Metadata embedding: (1024,)
# Annotator: 107045500887494395501503671156391276511438238350771804031511908341958511767225, Embedding shape: (1024,)
# Annotator: 33786780195049585363174228390648833021695753641853224823932028559628504111442, Embedding shape: (1024,)
#
# Filename: 258326.mp3
# Metadata embedding: (1024,)
# Annotator: 46121470561536803163280701579473790907008878615498467212527765029594050618063, Embedding shape: (1024,)
# Annotator: 53464569399578635112748285231005024932866458583911680643638500048780162363058, Embedding shape: (1024,)
#
# Filename: 258329.mp3
# Metadata embedding: (1024,)
# Annotator: 83668893003008678305118405095817913716497674204911163421851306056878320318153, Embedding shape: (1024,)
# Annotator: 89707952857497017702801712624756956146923507297260780078256408537217781166243, Embedding shape: (1024,)
#
# Filename: 259922.mp3
# Metadata embedding: (1024,)
# Annotator: 30597331778059837745124668163739384354258831399976129411899968136056814460611, Embedding shape: (1024,)
# Annotator: 79799466364488934541338726588780952383577975895800835054006422437422744913522, Embedding shape: (1024,)
#
# Filename: 26017.mp3
# Metadata embedding: (1024,)
# Annotator: 59535453388221859414776057874886065313858315756409120839410492187345784607095, Embedding shape: (1024,)
# Annotator: 93900312780166042846872832451895668515384271147306275299182344465701627046088, Embedding shape: (1024,)
#
# Filename: 260201.mp3
# Metadata embedding: (1024,)
# Annotator: 114398100589265666770019946027942814804640315983753935245254888684399451459314, Embedding shape: (1024,)
# Annotator: 99262612552325878298244668181556731091295316460923843379677871092286899210298, Embedding shape: (1024,)
#
# Filename: 260932.mp3
# Metadata embedding: (1024,)
# Annotator: 35149575729600094469332859178599505486187445313127624875957623647899891868542, Embedding shape: (1024,)
# Annotator: 37267084467437953951466893004748625829805521059700350064988574948839372758062, Embedding shape: (1024,)
#
# Filename: 261829.mp3
# Metadata embedding: (1024,)
# Annotator: 32628842571052558751508051662420881508159791165556082913666568300741825594048, Embedding shape: (1024,)
# Annotator: 40970781658716074858242873407421107733170539601283948175320548266647321464488, Embedding shape: (1024,)
#
# Filename: 262520.mp3
# Metadata embedding: (1024,)
# Annotator: 11168209049119697785284156939259715723838323298012206801210080796232413857942, Embedding shape: (1024,)
# Annotator: 3317414936298431696649139783659467911597120442929652646309738187785390246124, Embedding shape: (1024,)
#
# Filename: 26253.mp3
# Metadata embedding: (1024,)
# Annotator: 21915322070463801198423647818762039158521682809602587103552215082550618199837, Embedding shape: (1024,)
# Annotator: 48862512073162945459959687714911644771559423849078488155297076023003444481518, Embedding shape: (1024,)
#
# Filename: 262704.mp3
# Metadata embedding: (1024,)
# Annotator: 62355735792070369579481490774570832616665152146396382296147532179774877789611, Embedding shape: (1024,)
# Annotator: 68991112651884469867522519522057827653294389397099856072401566372288745963852, Embedding shape: (1024,)
#
# Filename: 26281.mp3
# Metadata embedding: (1024,)
# Annotator: 106081628063691536280231067634000531661252027108748144051353658655395634963236, Embedding shape: (1024,)
# Annotator: 68020275864064182121905129390182989385144444609311936672052662217184327997369, Embedding shape: (1024,)
#
# Filename: 264106.mp3
# Metadata embedding: (1024,)
# Annotator: 100333236523323873635701491776437452012511734958869982328013169408686230286600, Embedding shape: (1024,)
# Annotator: 105644655943619778281723194953926922011577676974010250804007784860760261225107, Embedding shape: (1024,)
#
# Filename: 264837.mp3
# Metadata embedding: (1024,)
# Annotator: 21731403352566939458290932445848497509228486043659747918552528793263295950144, Embedding shape: (1024,)
# Annotator: 31995799268170845192201207760198165804903621512687800939408131563063931367456, Embedding shape: (1024,)
#
# Filename: 264939.mp3
# Metadata embedding: (1024,)
# Annotator: 45405090319388515107991165305007922748491137584297090142332728711360792312878, Embedding shape: (1024,)
# Annotator: 59459710353809300990538585954543625498069905337512074229555445030258347839167, Embedding shape: (1024,)
#
# Filename: 266500.mp3
# Metadata embedding: (1024,)
# Annotator: 113160997761811326360045523441018522085460579083321546928079897819053774917750, Embedding shape: (1024,)
# Annotator: 38166745052496887069994378107692975296585346461051494344180693789505987975216, Embedding shape: (1024,)
#
# Filename: 267146.mp3
# Metadata embedding: (1024,)
# Annotator: 33018137475840129594541880713265157568391011704687325086895421422276311989192, Embedding shape: (1024,)
# Annotator: 5205755124099136934704458531175815755122499213604591541306002701912143415123, Embedding shape: (1024,)
#
# Filename: 267269.mp3
# Metadata embedding: (1024,)
# Annotator: 13549008949082137571545511001036411599928664550691768651216884027002149926942, Embedding shape: (1024,)
# Annotator: 77136153138153957648969923901745082593988972272307072898068289688617925694838, Embedding shape: (1024,)
#
# Filename: 26799.mp3
# Metadata embedding: (1024,)
# Annotator: 1576945196264367997531683002970449852988932779053679342197484577924850532788, Embedding shape: (1024,)
# Annotator: 77303111649669607137830086299452712637458216510998727246511180629500664192180, Embedding shape: (1024,)
#
# Filename: 268867.mp3
# Metadata embedding: (1024,)
# Annotator: 84192411679316422005283322795355018550221640435282090347791338384777524490139, Embedding shape: (1024,)
# Annotator: 91232267130641345824439720542152630048221954781236392317252938417249988218342, Embedding shape: (1024,)
#
# Filename: 272093.mp3
# Metadata embedding: (1024,)
# Annotator: 18625123121936993551823815191902498232842322537608721293487798493260616709459, Embedding shape: (1024,)
# Annotator: 52791938628006086357684805458892974749694017418510024490150941484388701905778, Embedding shape: (1024,)
#
# Filename: 272170.mp3
# Metadata embedding: (1024,)
# Annotator: 17724077227937458414465863830454887003973666009658126256100470469780980699120, Embedding shape: (1024,)
# Annotator: 90329676878045306461081102454884207055114643330210171773568099574637499545912, Embedding shape: (1024,)
#
# Filename: 272171.mp3
# Metadata embedding: (1024,)
# Annotator: 44589896010803436672245072799033713178243372334068801964814218397509764179359, Embedding shape: (1024,)
# Annotator: 83798156097639272746679852169789049963467405372196161228635156944547831524295, Embedding shape: (1024,)
#
# Filename: 272546.mp3
# Metadata embedding: (1024,)
# Annotator: 114398100589265666770019946027942814804640315983753935245254888684399451459314, Embedding shape: (1024,)
# Annotator: 27382730622967995848391116189571157454377392153442537092667631906718018890602, Embedding shape: (1024,)
#
# Filename: 272552.mp3
# Metadata embedding: (1024,)
# Annotator: 109459731900921774795172505742470442250557939301943177551266457608501976685162, Embedding shape: (1024,)
# Annotator: 111470609057027258204760356772901372667093782461401366104731370689359417330241, Embedding shape: (1024,)
#
# Filename: 273397.mp3
# Metadata embedding: (1024,)
# Annotator: 29997356935602131491632423114367107719990210402042857424045175141602823905383, Embedding shape: (1024,)
# Annotator: 40382604859536271998245780705284142626098162391950074214581127396656488358972, Embedding shape: (1024,)
#
# Filename: 273398.mp3
# Metadata embedding: (1024,)
# Annotator: 46121470561536803163280701579473790907008878615498467212527765029594050618063, Embedding shape: (1024,)
# Annotator: 57635733311314748899556841402932082724073216862549780021094218572796681062404, Embedding shape: (1024,)
#
# Filename: 273823.mp3
# Metadata embedding: (1024,)
# Annotator: 36523652429724867832162805348164187693953586177548906684789381551511497770389, Embedding shape: (1024,)
# Annotator: 82551235284309739653968008344814210311916058661833406739518790857443368745586, Embedding shape: (1024,)
#
# Filename: 277091.mp3
# Metadata embedding: (1024,)
# Annotator: 23893829303031423086404369130203592384888189169703851838429622705266671194466, Embedding shape: (1024,)
# Annotator: 57768994188635898453585596948260823503960977043569902094673919660879916194183, Embedding shape: (1024,)
#
# Filename: 277092.mp3
# Metadata embedding: (1024,)
# Annotator: 85069467606322681959652023504043707353468721093396593935422967892135230405738, Embedding shape: (1024,)
# Annotator: 93599868134001612328228589435004087662012545026542699120038015220920391547280, Embedding shape: (1024,)
#
# Filename: 30174.mp3
# Metadata embedding: (1024,)
# Annotator: 31399784615888520779712022413793685228274804251028833560156799174446262728298, Embedding shape: (1024,)
# Annotator: 42007950479082425063737052915855176969224440032882617579173734264596512642925, Embedding shape: (1024,)
#
# Filename: 30208.mp3
# Metadata embedding: (1024,)
# Annotator: 21539148972858706126981417398794527822929134931811933079636341755717901738182, Embedding shape: (1024,)
# Annotator: 6431647378238034395317169473724521494888400320565762508794496647897274359802, Embedding shape: (1024,)
#
# Filename: 30344.mp3
# Metadata embedding: (1024,)
# Annotator: 115270002470903402094009748375419749823454542819649441575263009926782328625557, Embedding shape: (1024,)
# Annotator: 59834231079874726832352853500753165275994271547741946784761013459073535287753, Embedding shape: (1024,)
#
# Filename: 316013.mp3
# Metadata embedding: (1024,)
# Annotator: 10892465509316365220502650175026973951304116600419136804347876697818021848547, Embedding shape: (1024,)
# Annotator: 49170229913260714455264004892366186828043132192653820001894273174821873841364, Embedding shape: (1024,)
#
# Filename: 316050.mp3
# Metadata embedding: (1024,)
# Annotator: 100089183809167624412319886016267345026042253447206416504227781766250814596242, Embedding shape: (1024,)
# Annotator: 90675002784724645719135968568905209515724062895163968745792672428867520585552, Embedding shape: (1024,)
#
# Filename: 316066.mp3
# Metadata embedding: (1024,)
# Annotator: 45669384786672331325616877274477248185156418900846805435422269081488597842513, Embedding shape: (1024,)
# Annotator: 94679287248510806505619816087719112608619861927317400417074958422719126377505, Embedding shape: (1024,)
#
# Filename: 316072.mp3
# Metadata embedding: (1024,)
# Annotator: 44346349317752316307531474790375206168213923240383539722619977044200122702563, Embedding shape: (1024,)
# Annotator: 5643895910032658602419824338095863857169372202088237514568704764249630469901, Embedding shape: (1024,)
#
# Filename: 317535.mp3
# Metadata embedding: (1024,)
# Annotator: 103976418446305420845959404964819672250101248156317177185454585813243326192207, Embedding shape: (1024,)
# Annotator: 58864092964652614671996668460845143199712161241153187413867581031635218825787, Embedding shape: (1024,)
#
# Filename: 319258.mp3
# Metadata embedding: (1024,)
# ...
#
# Filename: 741626.mp3
# Metadata embedding: (1024,)
# Annotator: 110061593356187988170123458075736909363258151655926678547037167213401751900241, Embedding shape: (1024,)
# Annotator: 69582610963371663743573649920842828901743347072739129727669537040269939692676, Embedding shape: (1024,)
#
# Filename: 742276.mp3
# Metadata embedding: (1024,)
# Annotator: 48862512073162945459959687714911644771559423849078488155297076023003444481518, Embedding shape: (1024,)
# Annotator: 62075910331128703179774468108358873115507569969151727340218991750105984715204, Embedding shape: (1024,)
#
# Filename: 742886.mp3
# Metadata embedding: (1024,)
# Annotator: 112371228566629488027497712581901251347743334869562648944080289713877118576261, Embedding shape: (1024,)
# Annotator: 18010983572885780349084641707931248738724916915271483109236355484529365029042, Embedding shape: (1024,)
#
# Filename: 743382.mp3
# Metadata embedding: (1024,)
# Annotator: 80951847488275215516695917610983541215527291417998427093511063342160000385503, Embedding shape: (1024,)
# Annotator: 94679287248510806505619816087719112608619861927317400417074958422719126377505, Embedding shape: (1024,)
#
# Filename: 744153.mp3
# Metadata embedding: (1024,)
# Annotator: 31995799268170845192201207760198165804903621512687800939408131563063931367456, Embedding shape: (1024,)
# Annotator: 49646555831625257015917138948745571881455758767163420374774183779692744338090, Embedding shape: (1024,)
#
# Filename: 74517.mp3
# Metadata embedding: (1024,)
# Annotator: 38599763158258377587061843824361077839924059800449427796068373682913539217434, Embedding shape: (1024,)
# Annotator: 77911310470423526869801569915069488805345185766638907351266805052657283315168, Embedding shape: (1024,)
#
# Filename: 746494.mp3
# Metadata embedding: (1024,)
# Annotator: 101604174054121622384228378106809892187920832103907325845324162692903802724599, Embedding shape: (1024,)
# Annotator: 87805567961116978481346376097272673745882266162160258559762904982999259135316, Embedding shape: (1024,)
#
# Filename: 749349.mp3
# Metadata embedding: (1024,)
# Annotator: 21731403352566939458290932445848497509228486043659747918552528793263295950144, Embedding shape: (1024,)
# Annotator: 85756756495929958175869382341127430683205456440970675913242264770435669956761, Embedding shape: (1024,)
#
# Filename: 75056.mp3
# Metadata embedding: (1024,)
# Annotator: 35224506475463891397846082096495080640679160230564846236190033374986882213270, Embedding shape: (1024,)
# Annotator: 87805567961116978481346376097272673745882266162160258559762904982999259135316, Embedding shape: (1024,)
#
# Filename: 75061.mp3
# Metadata embedding: (1024,)
# Annotator: 103399390517716422509339112576285492467124639608749074471864491760058786872916, Embedding shape: (1024,)
# Annotator: 103976418446305420845959404964819672250101248156317177185454585813243326192207, Embedding shape: (1024,)
#
# Filename: 751348.mp3
# Metadata embedding: (1024,)
# Annotator: 103899207086522017945911823197799983584796723346154550367911728736537654824996, Embedding shape: (1024,)
# Annotator: 94057971961546359846229431462387685271883384943446523429356802373347207481651, Embedding shape: (1024,)
#
# Filename: 75169.mp3
# Metadata embedding: (1024,)
# Annotator: 54020089824181856487207153336286365028222400294129612266063350557662298027402, Embedding shape: (1024,)
# Annotator: 69352328608713842319748499305385302938097298301188610902870387167745105941237, Embedding shape: (1024,)
#
# Filename: 751735.mp3
# Metadata embedding: (1024,)
# Annotator: 38599763158258377587061843824361077839924059800449427796068373682913539217434, Embedding shape: (1024,)
# Annotator: 82169704325376699758320540299966249817239490430264153076024080265213962953927, Embedding shape: (1024,)
#
# Filename: 752052.mp3
# Metadata embedding: (1024,)
# Annotator: 46874403415888587683289479114390627907224102675698904555162131250325224558564, Embedding shape: (1024,)
# Annotator: 72782441800300418808583652952484174451747915006966805944741970584276427864678, Embedding shape: (1024,)
#
# Filename: 752431.mp3
# Metadata embedding: (1024,)
# Annotator: 25599499054725754927183204694877296587842005676450590435595389613897528704286, Embedding shape: (1024,)
# Annotator: 71097486811686361953432820519834661510859245759465082945135801795142451534977, Embedding shape: (1024,)
#
# Filename: 752714.mp3
# Metadata embedding: (1024,)
# Annotator: 39358847788655878005405195354811234951615334821768774807711819715002313502489, Embedding shape: (1024,)
# Annotator: 48651420517301593163408743145312016877671450339716194127420938133056508603418, Embedding shape: (1024,)
#
# Filename: 753938.mp3
# Metadata embedding: (1024,)
# Annotator: 15743611799301375175009418580528890069851338810575075879119578048430725212613, Embedding shape: (1024,)
# Annotator: 32438032946794019062873876996796501941516731996597194323295176553760663360043, Embedding shape: (1024,)
#
# Filename: 754246.mp3
# Metadata embedding: (1024,)
# Annotator: 18934951173249346942957447943426816537870457850773795155716532942088148929592, Embedding shape: (1024,)
# Annotator: 76775683235442617648596312314365421075444993654323214201706882472761894464039, Embedding shape: (1024,)
#
# Filename: 757808.mp3
# Metadata embedding: (1024,)
# Annotator: 27293262522828174203196378455450922961191459192428430236877941429640823553993, Embedding shape: (1024,)
# Annotator: 97408140230628903907109109301849375849414026787115715155173749724926085470188, Embedding shape: (1024,)
#
# Filename: 760239.mp3
# Metadata embedding: (1024,)
# Annotator: 106911886166157606552394347668082919414947693521457064598390687700142985287061, Embedding shape: (1024,)
# Annotator: 75671903725790798317281121534672559287556880201287773235055134069257112043376, Embedding shape: (1024,)
#
# Filename: 765858.mp3
# Metadata embedding: (1024,)
# Annotator: 278073779453504337670053734016859883188739182188708052954748456899916808024, Embedding shape: (1024,)
# Annotator: 97408140230628903907109109301849375849414026787115715155173749724926085470188, Embedding shape: (1024,)
#
# Filename: 766274.mp3
# Metadata embedding: (1024,)
# Annotator: 100247029603858192446937081294697163617750733268242945965657002046650212321291, Embedding shape: (1024,)
# Annotator: 94057971961546359846229431462387685271883384943446523429356802373347207481651, Embedding shape: (1024,)
#
# Filename: 767134.mp3
# Metadata embedding: (1024,)
# Annotator: 1576945196264367997531683002970449852988932779053679342197484577924850532788, Embedding shape: (1024,)
# Annotator: 53337707496172741684125180427010811717700387520544676352570962962172231025747, Embedding shape: (1024,)
#
# Filename: 768678.mp3
# Metadata embedding: (1024,)
# Annotator: 33786780195049585363174228390648833021695753641853224823932028559628504111442, Embedding shape: (1024,)
# Annotator: 45450481666574546372750740813008441116285649811380379953850685538212673771047, Embedding shape: (1024,)
#
# Filename: 768918.mp3
# Metadata embedding: (1024,)
# Annotator: 42867469332459215984090181974491309564784967972641108761833013123393953003359, Embedding shape: (1024,)
# Annotator: 94057971961546359846229431462387685271883384943446523429356802373347207481651, Embedding shape: (1024,)
#
# Filename: 77021.mp3
# Metadata embedding: (1024,)
# Annotator: 11168209049119697785284156939259715723838323298012206801210080796232413857942, Embedding shape: (1024,)
# Annotator: 85247544917562590207669232265369485554402586734774147097525263757340943883745, Embedding shape: (1024,)
#
# Filename: 771249.mp3
# Metadata embedding: (1024,)
# Annotator: 59075493800294758042511046899055721009337983589516646257809703822386370686357, Embedding shape: (1024,)
# Annotator: 6995720596902748843208672390432937662271218262265423675134947986577677287362, Embedding shape: (1024,)
#
# Filename: 772967.mp3
# Metadata embedding: (1024,)
# Annotator: 29997356935602131491632423114367107719990210402042857424045175141602823905383, Embedding shape: (1024,)
# Annotator: 94979186708370371605411532602365988905946304532023110766393761397147268689362, Embedding shape: (1024,)
#
# Filename: 77685.mp3
# Metadata embedding: (1024,)
# Annotator: 104756685299042146837482008251463456417662964537684177690962768783435787306510, Embedding shape: (1024,)
# Annotator: 59535453388221859414776057874886065313858315756409120839410492187345784607095, Embedding shape: (1024,)
#
# Filename: 777608.mp3
# Metadata embedding: (1024,)
# Annotator: 52791938628006086357684805458892974749694017418510024490150941484388701905778, Embedding shape: (1024,)
# Annotator: 90627332917494795509922279088755507588547842436838961011936904562760761641746, Embedding shape: (1024,)
#
# Filename: 778364.mp3
# Metadata embedding: (1024,)
# Annotator: 100535866736783074762416578262272693273342178641522928107157452689480921183558, Embedding shape: (1024,)
# Annotator: 31512614764964277131807226414414116895613261979600454770293018928432798961173, Embedding shape: (1024,)
#
# Filename: 779871.mp3
# Metadata embedding: (1024,)
# Annotator: 17724077227937458414465863830454887003973666009658126256100470469780980699120, Embedding shape: (1024,)
# Annotator: 26073351235181780954515437889881027237537732239708063549963430833877522518498, Embedding shape: (1024,)
#
# Filename: 779876.mp3
# Metadata embedding: (1024,)
# Annotator: 106081628063691536280231067634000531661252027108748144051353658655395634963236, Embedding shape: (1024,)
# Annotator: 60119498162873744066729989322512518354854016359267673377547595127232780249564, Embedding shape: (1024,)
#
# Filename: 780526.mp3
# Metadata embedding: (1024,)
# Annotator: 106388760678737856887843740543254305455085099161586117919582237858847916941057, Embedding shape: (1024,)
# Annotator: 84704702810492203570508455757276662194775685610231578309011132791728316253685, Embedding shape: (1024,)
#
# Filename: 783997.mp3
# Metadata embedding: (1024,)
# Annotator: 55121482465506679224605825803506469881306248144699669975790603067132125825774, Embedding shape: (1024,)
# Annotator: 90175366125622214536158275984204973213956016267147912347697205194879952276970, Embedding shape: (1024,)
#
# Filename: 785393.mp3
# Metadata embedding: (1024,)
# Annotator: 18881987009468310036938990504199375630410943184810952187948229647847943348359, Embedding shape: (1024,)
# Annotator: 79870316315349615302327941860366026996801340811276116342195412772582394036186, Embedding shape: (1024,)
#
# Filename: 785479.mp3
# Metadata embedding: (1024,)
# Annotator: 69556124396360452165008314167974353738794538535686262260324093367842421170651, Embedding shape: (1024,)
# Annotator: 94057971961546359846229431462387685271883384943446523429356802373347207481651, Embedding shape: (1024,)
#
# Filename: 785667.mp3
# Metadata embedding: (1024,)
# Annotator: 21731403352566939458290932445848497509228486043659747918552528793263295950144, Embedding shape: (1024,)
# Annotator: 40382604859536271998245780705284142626098162391950074214581127396656488358972, Embedding shape: (1024,)
#
# Filename: 788020.mp3
# Metadata embedding: (1024,)
# Annotator: 31101202316044526867714413682512085535921849845543542326722684252077589848434, Embedding shape: (1024,)
# Annotator: 49646555831625257015917138948745571881455758767163420374774183779692744338090, Embedding shape: (1024,)
#
# Filename: 788203.mp3
# Metadata embedding: (1024,)
# Annotator: 20703981260002013510120757687613666097085158808725795979350977443443209529008, Embedding shape: (1024,)
# Annotator: 5066749238262937777735330933221191407821243639193437054829877133545692559010, Embedding shape: (1024,)
#
# Filename: 788919.mp3
# Metadata embedding: (1024,)
# Annotator: 103976418446305420845959404964819672250101248156317177185454585813243326192207, Embedding shape: (1024,)
# Annotator: 20078125797336961040030171255780273211544536169955386466869632633165496989903, Embedding shape: (1024,)
#
# Filename: 81195.mp3
# Metadata embedding: (1024,)
# Annotator: 49646555831625257015917138948745571881455758767163420374774183779692744338090, Embedding shape: (1024,)
# Annotator: 87805567961116978481346376097272673745882266162160258559762904982999259135316, Embedding shape: (1024,)
#
# Filename: 81801.mp3
# Metadata embedding: (1024,)
# Annotator: 112621813320324920368310880723930126727267829622388552253741403508590413765479, Embedding shape: (1024,)
# Annotator: 40970781658716074858242873407421107733170539601283948175320548266647321464488, Embedding shape: (1024,)
#
# Filename: 81806.mp3
# Metadata embedding: (1024,)
# Annotator: 112564115413485089702850121337141539667485578084293487010818286715173652551704, Embedding shape: (1024,)
# Annotator: 5066749238262937777735330933221191407821243639193437054829877133545692559010, Embedding shape: (1024,)
#
# Filename: 84127.mp3
# Metadata embedding: (1024,)
# Annotator: 68020275864064182121905129390182989385144444609311936672052662217184327997369, Embedding shape: (1024,)
# Annotator: 98480739383670862732235015446138449951778105075809132411788391530436419955353, Embedding shape: (1024,)
#
# Filename: 84391.mp3
# Metadata embedding: (1024,)
# Annotator: 104939711832149768694494655178082454250596446871785307842477905317981921370100, Embedding shape: (1024,)
# Annotator: 84466794410457351601971456505565394664569532650248170238079880672835248290675, Embedding shape: (1024,)
#
# Filename: 86051.mp3
# Metadata embedding: (1024,)
# Annotator: 37354286634043723116058383740855729941019794941266091207799662530452573074208, Embedding shape: (1024,)
# Annotator: 84502834521198386862034138584790973198130542413073556542036852105503584126185, Embedding shape: (1024,)
#
# Filename: 87130.mp3
# Metadata embedding: (1024,)
# Annotator: 1292939867854418856993626592299469310896234854975569301082336183247273898661, Embedding shape: (1024,)
# Annotator: 35989618103097873742543037543234189200471817266603394841653680521045986966472, Embedding shape: (1024,)
#
# Filename: 91761.mp3
# Metadata embedding: (1024,)
# Annotator: 52774512441422001482295385443052285592026321448521831257057994761101460318087, Embedding shape: (1024,)
# Annotator: 54020089824181856487207153336286365028222400294129612266063350557662298027402, Embedding shape: (1024,)
#
# Filename: 94017.mp3
# Metadata embedding: (1024,)
# Annotator: 64368141419366353231248153947800598854301986961326580320203678560534249792401, Embedding shape: (1024,)
# Annotator: 68946096525553517837301244669921520452233607944530604744485124623740136078067, Embedding shape: (1024,)
#
# Filename: 9554.mp3
# Metadata embedding: (1024,)
# Annotator: 84704702810492203570508455757276662194775685610231578309011132791728316253685, Embedding shape: (1024,)
# Annotator: 98156558448106268043595687228862557017562074968028544225755226975716671693205, Embedding shape: (1024,)
#
# Filename: 95547.mp3
# Metadata embedding: (1024,)
# Annotator: 56413362525526829042224111294180020055817089934652032214609784221226226919283, Embedding shape: (1024,)
# Annotator: 62883765306800336674960299070997168485387625840275185443012937071154406071377, Embedding shape: (1024,)
#
# Filename: 96847.mp3
# Metadata embedding: (1024,)
# Annotator: 114697563938404661396945902701797315715132465023441131092443637938676177963693, Embedding shape: (1024,)
# Annotator: 278073779453504337670053734016859883188739182188708052954748456899916808024, Embedding shape: (1024,)
#
# Filename: 96855.mp3
# Metadata embedding: (1024,)
# Annotator: 64225297528290238697712837925878397213863871009284151866342417004528933766418, Embedding shape: (1024,)
# Annotator: 84502834521198386862034138584790973198130542413073556542036852105503584126185, Embedding shape: (1024,)
#
# Filename: 97613.mp3
# Metadata embedding: (1024,)
# Annotator: 54020089824181856487207153336286365028222400294129612266063350557662298027402, Embedding shape: (1024,)
# Annotator: 93599868134001612328228589435004087662012545026542699120038015220920391547280, Embedding shape: (1024,)
#
# Filename: 97614.mp3
# Metadata embedding: (1024,)
# Annotator: 16645546140722306861957385955702985749448124934040871229453560983102139466669, Embedding shape: (1024,)
# Annotator: 20546297406041413108126944669340850369236459961139398489918929227196808618116, Embedding shape: (1024,)
#
# Filename: 98014.mp3
# Metadata embedding: (1024,)
# Annotator: 411636573135802475484269253664194870658670826351810573916181360144468290346, Embedding shape: (1024,)
# Annotator: 72470746904509111117830031798685958966753183658195427323003341196053753167906, Embedding shape: (1024,)

# %%
most_dissimilar_between_annotators = []

for filename, embeddings in comparison_dict.items():

    metadata_embedding = embeddings['metadata_embedding']
    annotation_embeddings = embeddings['annotation_embeddings']

    annotators = list(annotation_embeddings.keys())
    for i in range(len(annotators)):
        for j in range(i + 1, len(annotators)):
            annotator_i = annotators[i]
            annotator_j = annotators[j]

            embedding_i = annotation_embeddings[annotator_i]
            embedding_j = annotation_embeddings[annotator_j]

            cos_sim = np.dot(embedding_i, embedding_j) / (np.linalg.norm(embedding_i) * np.linalg.norm(embedding_j))

            most_dissimilar_between_annotators.append((filename, cos_sim))

most_dissimilar_between_annotators.sort(key=lambda x: x[1])
print(most_dissimilar_between_annotators)
# Out:
# [('568273.mp3', np.float32(-0.1142988)), ('258329.mp3', np.float32(-0.046190973)), ('777608.mp3', np.float32(-0.046047233)), ('32366.mp3', np.float32(0.0021451926)), ('560537.mp3', np.float32(0.0038312178)), ('400796.mp3', np.float32(0.029149987)), ('166643.mp3', np.float32(0.037692312)), ('476910.mp3', np.float32(0.05651084)), ('785667.mp3', np.float32(0.06621949)), ('17530.mp3', np.float32(0.070221215)), ('563257.mp3', np.float32(0.07915899)), ('442374.mp3', np.float32(0.07954522)), ('684932.mp3', np.float32(0.07957395)), ('565104.mp3', np.float32(0.09083017)), ('51147.mp3', np.float32(0.092525095)), ('650419.mp3', np.float32(0.09592077)), ('160769.mp3', np.float32(0.10068659)), ('685996.mp3', np.float32(0.10711498)), ('501174.mp3', np.float32(0.1086122)), ('627057.mp3', np.float32(0.111610614)), ('677686.mp3', np.float32(0.11874445)), ('210034.mp3', np.float32(0.12158071)), ('407115.mp3', np.float32(0.122354515)), ('783997.mp3', np.float32(0.1274258)), ('341046.mp3', np.float32(0.12768042)), ('637068.mp3', np.float32(0.12920222)), ('736033.mp3', np.float32(0.13467568)), ('482014.mp3', np.float32(0.14093836)), ('504174.mp3', np.float32(0.14209294)), ('708560.mp3', np.float32(0.14303933)), ('538877.mp3', np.float32(0.14451164)), ('743382.mp3', np.float32(0.14642188)), ('433725.mp3', np.float32(0.14799727)), ('637435.mp3', np.float32(0.14977077)), ('264939.mp3', np.float32(0.1575716)), ('639554.mp3', np.float32(0.16152063)), ('651319.mp3', np.float32(0.16552737)), ('566865.mp3', np.float32(0.16578276)), ('753938.mp3', np.float32(0.16692527)), ('583296.mp3', np.float32(0.16832457)), ('165265.mp3', np.float32(0.16891353)), ('757808.mp3', np.float32(0.16935635)), ('119173.mp3', np.float32(0.1715013)), ('26017.mp3', np.float32(0.17393918)), ('353140.mp3', np.float32(0.17426844)), ('361590.mp3', np.float32(0.17715633)), ('161883.mp3', np.float32(0.17968546)), ('96855.mp3', np.float32(0.18039986)), ('535624.mp3', np.float32(0.18116216)), ('122978.mp3', np.float32(0.18410707)), ('453245.mp3', np.float32(0.18474278)), ('134783.mp3', np.float32(0.18523368)), ('437867.mp3', np.float32(0.18558547)), ('570654.mp3', np.float32(0.18592969)), ('573621.mp3', np.float32(0.18752988)), ('648903.mp3', np.float32(0.18775956)), ('785479.mp3', np.float32(0.19062454)), ('563846.mp3', np.float32(0.19477127)), ('86051.mp3', np.float32(0.19692755)), ('666178.mp3', np.float32(0.20492645)), ('779876.mp3', np.float32(0.21158856)), ('616854.mp3', np.float32(0.21531154)), ('213364.mp3', np.float32(0.21702448)), ('449576.mp3', np.float32(0.22300534)), ('169236.mp3', np.float32(0.22467145)), ('159437.mp3', np.float32(0.22758125)), ('44698.mp3', np.float32(0.2286183)), ('122956.mp3', np.float32(0.23055653)), ('486271.mp3', np.float32(0.23219845)), ('81806.mp3', np.float32(0.24004582)), ('634676.mp3', np.float32(0.24170084)), ('456420.mp3', np.float32(0.24551633)), ('170316.mp3', np.float32(0.24615012)), ('409145.mp3', np.float32(0.24859466)), ('560530.mp3', np.float32(0.24887407)), ('438659.mp3', np.float32(0.24902081)), ('523338.mp3', np.float32(0.25041375)), ('666579.mp3', np.float32(0.25063646)), ('580464.mp3', np.float32(0.2517901)), ('646601.mp3', np.float32(0.2544431)), ('361056.mp3', np.float32(0.25711045)), ('84391.mp3', np.float32(0.2573395)), ('691536.mp3', np.float32(0.25956127)), ('407115.mp3', np.float32(0.2609174)), ('384360.mp3', np.float32(0.2619165)), ('699398.mp3', np.float32(0.26652047)), ('529826.mp3', np.float32(0.26770124)), ('721564.mp3', np.float32(0.26961654)), ('486512.mp3', np.float32(0.27320698)), ('660258.mp3', np.float32(0.2742042)), ('372607.mp3', np.float32(0.27574554)), ('376827.mp3', np.float32(0.27991855)), ('110921.mp3', np.float32(0.28117302)), ('352225.mp3', np.float32(0.28205436)), ('679112.mp3', np.float32(0.28547284)), ('660256.mp3', np.float32(0.28614908)), ('652478.mp3', np.float32(0.28775454)), ('111059.mp3', np.float32(0.2878124)), ('714974.mp3', np.float32(0.28889498)), ('625717.mp3', np.float32(0.2918183)), ('33677 ...

# %%
print("largest difference:")
ex_file = most_dissimilar_between_annotators[0][0]
meta = df_metadata[df_metadata['filename'] == ex_file][['filename', 'title', 'keywords', 'description']]
print(meta)

print(meta['title'].values)
print(meta['keywords'].values)
print(meta['description'].values)
# Out:
# Most dissimilar:
#         filename                                              title  \
# 5182  568273.mp3  spectral violin drone processed through granul...
#
#                                                keywords  \
# 5182  spectral, tonal, granulation, horror, drone, d...
#
#                                             description
# 5182  i've gone to a lot of classical music concerts...
# ['spectral violin drone processed through granulation and reverb']
# ['spectral, tonal, granulation, horror, drone, dark, avant-garde, ambient, violin, soundscape, experimental']
# ['i\'ve gone to a lot of classical music concerts. i often bring my zoom h2n in my jacket pocket.  this sound is a snippet of one of the live recordings i took from a concert in la. i have no idea the name of the piece of music. i ran the recording through several instances of salty grain vst, then through filterjam by audiothing (free), then out through valhalla\'s super massive (free) - then leveled a bit with the great free "loudmax" vst. i highly recommend all those plugins.  \n\npotential use cases for this sound: as a backdrop for some budget film (indy horror film sound persons: your welcome!), pitch it up 12 octaves and run it through the paulstretch vst plugin, pitched way down in the plugin.  reverse this and use it as a carrier of a vocoder while you sing your next mega pop hit lyrics through it.']

# %%
filtered_annot = df_annotations[df_annotations['filename'] == ex_file]
print(filtered_annot)

annotators = filtered_annot['annotator'].unique()
print(annotators)
# Out:
#          task_id    filename  \
# 7323   161989536  568273.mp3
# 27703  161989536  568273.mp3
#
#                                                annotator  \
# 7323   3816674505249688706999437810769297529658534646...
# 27703  6740345789110869605635392751382589427715708003...
#
#                                                     text  onset     offset  \
# 7323    A sharp, loud violin plays rapidly at a concert.    0.0  20.073243
# 27703  A sustained ambient drone with granular and sp...    0.0  20.028386
#
#                                          filename_unsafe
# 7323   568273_spectral violin drone processed through...
# 27703  568273_spectral violin drone processed through...
# ['38166745052496887069994378107692975296585346461051494344180693789505987975216'
#  '67403457891108696056353927513825894277157080037650893722622884910463124172564']

# %%
filtered_annot_1 = filtered_annot[filtered_annot['annotator'] == annotators[0]].agg(lambda x: list(x)).reset_index()
filtered_annot_2 = filtered_annot[filtered_annot['annotator'] == annotators[1]].agg(lambda x: list(x)).reset_index()

print(filtered_annot_1['text'].values)
print(filtered_annot_2['text'].values)

Audio(PATH_TO_DATASET + "/audio/" + ex_file)
# Out:
# ['A sharp, loud violin plays rapidly at a concert.']
# ['A sustained ambient drone with granular and spectral textures. ']
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("highest similarity:")
ex_file = most_dissimilar_between_annotators[-1][0]
meta = df_metadata[df_metadata['filename'] == ex_file][['filename', 'title', 'keywords', 'description']]
print(meta)

print(meta['title'].values)
print(meta['keywords'].values)
print(meta['description'].values)
# Out:
# highest similarity:
#         filename                                         title  \
# 6104  203149.mp3  End of the afternoon in a field, in Nebraska
#
#                                                keywords  \
# 6104  CD130519T018, felix, cows, singing, birds, end...
#
#                                             description
# 6104  Cows and bulls calling and mooing, bird singin...
# ['End of the afternoon in a field, in Nebraska']
# ['CD130519T018, felix, cows, singing, birds, end, usa, field, call, bird, evening, countryside, bulls, moo, bull, sing, mooing, blume, calls, cow, fields, calling, nebraska, afternoon']
# ['Cows and bulls calling and mooing, bird singing, the end of the afternoon in the countryside...\r\nRecorded around a pound in the countryside of Nebraska (USA), at the end of the day.\r\n\r\nSound recorded by a MS setup Schoeps CCM41+CCM8\r\nSound Devices 788T recorder with CL8\r\nMS is encoded in STEREO Left-Right\r\nrecorded in may 2013 in Nebraska, USA.\r\nSound Reference: @CD130519T018\r\n\r\nmore sounds on www.felixblume.com\r\n\r\nPlease rate or comment the sound if you like it!']

# %%
filtered_annot = df_annotations[df_annotations['filename'] == ex_file]
print(filtered_annot)

annotators = filtered_annot['annotator'].unique()
print(annotators)
# Out:
#          task_id    filename  \
# 864    161978386  203149.mp3
# 4228   161978386  203149.mp3
# 5080   161978386  203149.mp3
# 13107  161978386  203149.mp3
# 13834  161978386  203149.mp3
# 17270  161978386  203149.mp3
# 20461  161978386  203149.mp3
# 20575  161978386  203149.mp3
# 21397  161978386  203149.mp3
# 21454  161978386  203149.mp3
# 26460  161978386  203149.mp3
# 29140  161978386  203149.mp3
# 30194  161978386  203149.mp3
# 31889  161978386  203149.mp3
# 33555  161978386  203149.mp3
#
#                                                annotator  \
# 864    8379815609763927274667985216978904996346740537...
# 4228   8379815609763927274667985216978904996346740537...
# 5080   8379815609763927274667985216978904996346740537...
# 13107  8379815609763927274667985216978904996346740537...
# 13834  8379815609763927274667985216978904996346740537...
# 17270  8379815609763927274667985216978904996346740537...
# 20461  8379815609763927274667985216978904996346740537...
# 20575  8379815609763927274667985216978904996346740537...
# 21397  8379815609763927274667985216978904996346740537...
# 21454  5534034081322341532863092552845873228631139501...
# 26460  8379815609763927274667985216978904996346740537...
# 29140  5534034081322341532863092552845873228631139501...
# 30194  8379815609763927274667985216978904996346740537...
# 31889  8379815609763927274667985216978904996346740537...
# 33555  8379815609763927274667985216978904996346740537...
#
#                                     text      onset     offset  \
# 864    cows and bulls calling and mooing   3.312045   5.025971
# 4228   Cows and bulls calling and mooing   0.764318   1.250702
# 5080                       Birds singing   1.876054   3.335206
# 13107  birds singing in the country side   0.046322   0.602190
# 13834                     Birds singiing  19.131114  20.173365
# 17270                      Birds singing   1.273863   1.737087
# 20461                      Birds singing  23.184316  24.133923
# 20575             Cows and bulls calling   1.273863   1.737087
# 21397                      Birds singing   4.145847   7.434731
# 21454              cows and bulls mooing   0.064283  24.191995
# 26460  Cows and bulls calling and mooing   1.760248   2.431921
# 29140                      birds singing   0.064283  24.191995
# 30194  cows and bulls calling and mooing  21.655679  23.045349
# 31889  Cows and bulls calling and mooing   6.647251  14.753655
# 33555                      birds singing  14.915783  17.834089
#
#                                          filename_unsafe
# 864    203149_End of the afternoon in a field in Nebr...
# 4228   203149_End of the afternoon in a field in Nebr...
# 5080   203149_End of the afternoon in a field in Nebr...
# 13107  203149_End of the afternoon in a field in Nebr...
# 13834  203149_End of the afternoon in a field in Nebr...
# 17270  203149_End of the afternoon in a field in Nebr...
# 20461  203149_End of the afternoon in a field in Nebr...
# 20575  203149_End of the afternoon in a field in Nebr...
# 21397  203149_End of the afternoon in a field in Nebr...
# 21454  203149_End of the afternoon in a field in Nebr...
# 26460  203149_End of the afternoon in a field in Nebr...
# 29140  203149_End of the afternoon in a field in Nebr...
# 30194  203149_End of the afternoon in a field in Nebr...
# 31889  203149_End of the afternoon in a field in Nebr...
# 33555  203149_End of the afternoon in a field in Nebr...
# ['83798156097639272746679852169789049963467405372196161228635156944547831524295'
#  '55340340813223415328630925528458732286311395013930503995352353850108948193755']

# %%
filtered_annot_1 = filtered_annot[filtered_annot['annotator'] == annotators[0]].agg(lambda x: list(x)).reset_index()
filtered_annot_2 = filtered_annot[filtered_annot['annotator'] == annotators[1]].agg(lambda x: list(x)).reset_index()

print(filtered_annot_1['text'].values)
print(filtered_annot_2['text'].values)

Audio(PATH_TO_DATASET + "/audio/" + ex_file)
# Out:
# ['cows and bulls calling and mooing' 'Cows and bulls calling and mooing'
#  'Birds singing' 'birds singing in the country side' 'Birds singiing'
#  'Birds singing' 'Birds singing' 'Cows and bulls calling' 'Birds singing'
#  'Cows and bulls calling and mooing' 'cows and bulls calling and mooing'
#  'Cows and bulls calling and mooing' 'birds singing']
# ['cows and bulls mooing' 'birds singing']
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
df_metadata_manu_count.merge()


df_annotations_manu_count = metadata.loc[metadata['manufacturer'] == 'FullMetalJedi', 'keywords']

print("df_annotations_n_manu.shape: \t", df_annotations_n_manu.shape)

#df_annotations_n_manu[["keywords", "manufacturer", "description", "text", "onset", "offset", "filename_unsafe"]].head(n=20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df_annotations_manu_count = metadata.loc[metadata['manufacturer'] == 'FullMetalJedi', 'keywords']
#       3 print("df_annotations_n_manu.shape: \t", df_annotations_n_manu.shape)
#       5 #df_annotations_n_manu[["keywords", "manufacturer", "description", "text", "onset", "offset", "filename_unsafe"]].head(n=20)
#
# NameError: name 'metadata' is not defined

# %%
df_annotations_n_manu.loc[["514223.mp3", "388060.mp3", "417598.mp3"], ["task_id", "annotator"]]
# Out:
#               task_id                                          annotator
# filename
# 514223.mp3  161991794  2191532207046380119842364781876203915852168280...
# 514223.mp3  161991794  2191532207046380119842364781876203915852168280...
# 388060.mp3  161985403  4545048166657454637275074081300844111628564981...
# 388060.mp3  161985403  4545048166657454637275074081300844111628564981...
# 388060.mp3  161985403  4545048166657454637275074081300844111628564981...
# 388060.mp3  161985403  4545048166657454637275074081300844111628564981...
# 388060.mp3  161985403  4545048166657454637275074081300844111628564981...
# 388060.mp3  161985403  4545048166657454637275074081300844111628564981...
# 388060.mp3  161985403  4545048166657454637275074081300844111628564981...
# 388060.mp3  161985403  4545048166657454637275074081300844111628564981...
# 388060.mp3  161985403  4545048166657454637275074081300844111628564981...
# 388060.mp3  161985403  4545048166657454637275074081300844111628564981...
# 388060.mp3  161985403  4545048166657454637275074081300844111628564981...
# 388060.mp3  161985403  4545048166657454637275074081300844111628564981...
# 388060.mp3  161985403  4545048166657454637275074081300844111628564981...
# 417598.mp3  161982873  8129535617059876176536104196921940588127964024...
# 417598.mp3  161982873  8129535617059876176536104196921940588127964024...
# 417598.mp3  161982873  8129535617059876176536104196921940588127964024...

# %%
# select a column
metadata['keywords']
metadata.loc[:, 'keywords'].head(n=3)
# Out:
# filename
# 221934.mp3    engine, christian, field-recording, people, la...
# 396529.mp3    Playground, Child-Play, Ambience, Hammering, N...
# 450016.mp3    motocross, dirt, idle, bike, motorcycle, revs,...
# Name: keywords, dtype: object

# %% [markdown]
# - the result is a `pd.Series` object
# - use `.loc[ROWS, COLUMN]` for a more fine-grained selection
# - `:` selects everything

# %% [markdown]
# ## Select multiple columns
#
# To select multiple columns, provide a list of column names in the square brackets:

# %%
metadata[['title', 'keywords']]
metadata.loc[:, ['title', 'keywords']].head(n=3)
# Out:
#                                                         title  \
# filename
# 221934.mp3              meeting singing on boat - galilee.wav
# 396529.mp3                               Baltic Shipyard3.wav
# 450016.mp3  motorcycle dirt bike motocross idle stationary...
#
#                                                      keywords
# filename
# 221934.mp3  engine, christian, field-recording, people, la...
# 396529.mp3  Playground, Child-Play, Ambience, Hammering, N...
# 450016.mp3  motocross, dirt, idle, bike, motorcycle, revs,...

# %% [markdown]
# - the result is a `pd.DataFrame`object
# - use `.loc[ROWS, COLUMNS]` for a more fine grained selection

# %% [markdown]
# ## Select a row

# %% [markdown]
# Use `.loc` to select a row based on the index (filename)

# %%
metadata.loc['450016.mp3']
# Out:
# keywords         motocross, dirt, idle, bike, motorcycle, revs,...
# freesound_id                                                450016
# sound_link       https://freesound.org/people/kyles/sounds/450016/
# manufacturer                                                 kyles
# license          http://creativecommons.org/publicdomain/zero/1.0/
# title            motorcycle dirt bike motocross idle stationary...
# description      motorcycle dirt bike motocross idle stationary...
# num_downloads                                                  101
# geotag                                                         NaN
# start_time_s                                                  11.8
# end_time_s                                                  38.885
# Name: 450016.mp3, dtype: object

# %% [markdown]
# - the result is a `pd.Series`

# %% [markdown]
# ## Select multiple rows
#
# Use `.loc` with a list of indices (filenames) to select multiple rows:

# %%
metadata.loc[['438858.mp3', '128446.mp3'], ["title", "manufacturer"]]
# Out:
#                              title manufacturer
# filename
# 438858.mp3  G55-04-Cannon Wind.wav   craigsmith
# 128446.mp3         chain ferry.WAV    inchadney

# %% [markdown]
# Use `.loc`to select multiple rows based on a [slice](https://stackoverflow.com/questions/509211/how-slicing-in-python-works):

# %%
metadata.loc[::2, ["title", "manufacturer"]].head(n=2)
# Out:
#                                                         title    manufacturer
# filename
# 221934.mp3              meeting singing on boat - galilee.wav  thatjeffcarter
# 450016.mp3  motorcycle dirt bike motocross idle stationary...           kyles

# %% [markdown]
# - slice `::2` selects every second element
# - the result is a `pd.DataFrame`

# %% [markdown]
# ## Select rows based on a condition
#
# Quite often we'd like to select rows based on a condition.
#
# To do so, use elementwise comparison and create a Series with True/ False values:

# %%
(metadata['manufacturer'] == 'FullMetalJedi').head(n=3)
# Out:
# filename
# 221934.mp3    False
# 396529.mp3     True
# 450016.mp3    False
# Name: manufacturer, dtype: bool

# %% [markdown]
# - maps index (filename) to True/ False

# %% [markdown]
# Use this alignable sequence to select rows for which the condition is True:

# %%
metadata.loc[metadata['manufacturer'] == 'FullMetalJedi', 'keywords']
# Out:
# filename
# 396529.mp3    Playground, Child-Play, Ambience, Hammering, N...
# 530143.mp3    Yard, Winter, Crow, Horn, Window, Train, Dista...
# 530125.mp3           Meow, Fake, Kitty, Lips, Imitation, Kitten
# 396528.mp3    Industrial, Hit, Baltic-Shipyard, Metal, Echoe...
# Name: keywords, dtype: object

# %% [markdown]
# ## How many files do we have per manufacturer?
#
# We might've downloaded too many files from a single manufacturer.
#
# Let's check how many audio files we did collect from each of them.
#
# Use `.value_counts()` to get a series with counts of unique values:

# %%
manufacturer_counts = metadata["manufacturer"].value_counts()
manufacturer_counts.head(n=3)
# Out:
# manufacturer
# klankbeeld     94
# felix.blume    74
# kyles          67
# Name: count, dtype: int64

# %% [markdown]
# - result is a `pd.Series`
# - index are the unique values of column ("manufactuer")

# %% [markdown]
# ## Some simple statistics
#
# We don't want to look through all counts...
#
# Let's compute some simple summary statistics.
#
# Use `.min()`, `.max()`, `.mean()`, `.meadian()` on a column to compute simple summary statistics:

# %%
print("Min: ", manufacturer_counts.min())
print("Max: ", manufacturer_counts.max())
print("Mean: ", manufacturer_counts.mean())
print("Median: ", manufacturer_counts.median())
# Out:
# Min:  1
# Max:  94
# Mean:  1.9436345966958213
# Median:  1.0

# %% [markdown]
# ## A histogram
#
# Or even better: let's plot the distribution of manufacturer counts!
#
#
# To plot the distribution of values use `.plot.hist(bins=n_bins, figsize=(width, height))`

# %%
import matplotlib.pyplot as plt
plt.title("Histogram of Manufacturer Counts")
manufacturer_counts.plot.hist(bins=manufacturer_counts.max(), figsize=(7, 4))
plt.xlabel("Manufacturer Counts")
plt.show()

# %% [markdown]
# - `plt.title(TITLE)` to add a title
# - `plt.xlabel(X_LABEL)` to add a label for the horizontal axis
# - `plt.ylabel(Y_LABEL)` to add a label for the vertical axis
# - `plt.xticks(LIST_OF_INDICES, LIST_OF_DISPLAYED_NAMES_IN_PLOT)` to change the default ticks on the x axis

# %% [markdown]
# ## Transforming Columns
#
# Quite often, we want to introduce new columns based on values in the other column.
#
# To create a new column based on an existing one, we can use method `.transform(function)`:

# %%
metadata[['keywords']].head(n=2)
# Out:
#                                                      keywords
# filename
# 221934.mp3  engine, christian, field-recording, people, la...
# 396529.mp3  Playground, Child-Play, Ambience, Hammering, N...

# %% [markdown]
# Let's create a new column that is True if one of the keywords relates to bad weather:

# %%
def is_bad_weather(keywords: str):
    return 'rain' in keywords or 'storm' in keywords or 'thunder' in keywords or 'lightning' in keywords

metadata["bad_weather"] = metadata["keywords"].transform(is_bad_weather)
metadata["bad_weather"].value_counts()
# Out:
# bad_weather
# False    1767
# True      233
# Name: count, dtype: int64

# %%
metadata.loc[metadata["bad_weather"] == True, ["title", "keywords"]].head(n=3)
# Out:
#                                                         title  \
# filename
# 486601.mp3                            Rain on bowl with water
# 440488.mp3             Raining on the Glass Window 20180905-3
# 667706.mp3  Train passing 300 meters away with loud horn, ...
#
#                                                      keywords
# filename
# 486601.mp3   water, raindrops, weather, bowl-with-water, rain
# 440488.mp3              thunder, weather, storm, rain, nature
# 667706.mp3  cricket, blowing, Blume, field-recording, dusk...

# %% [markdown]
# ## Task 1.1: Load annotations.csv
#
# - use `pd.read_csv(os.path.join(PATH_TO_DATASET, "annotations.csv"))` to load the file and store te result into variable `annotations`

# %%
annotations = pd.read_csv(os.path.join(PATH_TO_DATASET, "annotations.csv")) # I replace 'None'
annotations[["filename", "annotator", "onset", "offset", "text"]].head(n = 3) # task_id,filename,annotator,text,onset,offset,filename_unsafe
# Out:
#      filename                                          annotator      onset  \
# 0  387455.mp3  1064150219469060099272839550690797785059878008...  25.777629
# 1  388060.mp3  4545048166657454637275074081300844111628564981...   4.315161
# 2  554853.mp3  8880859324073821414854467373956855581335518056...   0.786800
#
#       offset                                               text
# 0  26.516667  Light metallic sound like a light metallic cha...
# 1   5.336709  Clear sound of hitting metallic object on an a...
# 2   0.938108               Someone stepping on concrete loudly.

# %% [markdown]
# ## Task 1.2: Shape of the table
#
# - complete the print statements

# %%
print("DataFrame shape: \t", annotations.shape) # I replace 'None)'
print("DataFrame rows: \t", len(annotations.index)) # I replace 'None)'
print("DataFrame columns: \t", len(annotations.columns)) # I replace 'None)'
print("DataFrame column names: \n", annotations.columns.to_list()) # I replace 'None)'
# Out:
# DataFrame shape: 	 (7975, 7)
# DataFrame rows: 	 7975
# DataFrame columns: 	 7
# DataFrame column names:
#  ['task_id', 'filename', 'annotator', 'text', 'onset', 'offset', 'filename_unsafe']

# %% [markdown]
# ## Task 1.3: How many annotations per file did we collect?
#
# - count the number of annotations per file using `.value_counts()`
# - compute simple summary statistics and complete the print statements

# %%
annotations_per_file = annotations["annotator"].value_counts() # I replace 'None'

print("Min: ",  annotations_per_file.min()) # I replace 'None)
print("Max: ",  annotations_per_file.max()) # I replace 'None)
print("Mean: ",  annotations_per_file.mean()) # I replace 'None)
print("Median: ", annotations_per_file.median()) # I replace 'None)
# Out:
# Min:  1
# Max:  112
# Mean:  24.46319018404908
# Median:  21.0

# %% [markdown]
# ## Task 1.4: Plot a histogram or barplot of the annotations per file
#
# - use `.plot.hist(bins=annotations_per_file.max(), figsize=(10, 3))`
# - add labels for the horizontal and vertical axes

# %%
annotations_per_file.plot.hist(bins=annotations_per_file.max(), figsize=(10, 3))

plt.title("Histogram of Annotations per File")
plt.xlabel("Number of Annotations")

plt.show() 
plt.savefig('annotations_per_file.png') # to store it on the hard drive

# %% [markdown]
# ## How long are these temporal annotations?
#
# There's no column with the duration in the annotations data frame. Can we compute it?

# %%
annotations[["filename", "onset", "offset", "text"]].head(n = 2)
# Out:
#      filename      onset     offset  \
# 0  387455.mp3  25.777629  26.516667
# 1  388060.mp3   4.315161   5.336709
#
#                                                 text
# 0  Light metallic sound like a light metallic cha...
# 1  Clear sound of hitting metallic object on an a...

# %% [markdown]
# - subtract `annotations[offset]` from `annotations['onset']` to get a new column
# - assign the result to a new column `annotations['duration']`
# - use `.plot.hist(bins=metadata['duration'].max(), figsize=(10, 5))`

# %%
annotations["duration"] = annotations["offset"] - annotations["onset"]
annotations["duration"].plot.hist(bins=100, figsize=(10, 3))
plt.show()

# %% [markdown]
# ## Grouping
#
# Quite often, we're interested in comparing statistics for different groups.
#
# We can group the table by distinct values in a column using `.groupby(COLUMN_NAME)` and compute statistics for each group:

# %%
median_duration_per_annotator = annotations.groupby("annotator")["duration"].median()
median_duration_per_annotator.head(n=3)
# Out:
# annotator
# 100085476285274256355828104148824375899078643541741339916509444476406988392584    1.006873
# 100089183809167624412319886016267345026042253447206416504227781766250814596242    3.209427
# 100244901742626191928938396361966568568817162902949675108480834100485871510410    1.002949
# Name: duration, dtype: float64

# %% [markdown]
# - gives the median annotation duration for each annotator

# %%
plt.title("Histogram of Annotation Timespan per Annotator")
median_duration_per_annotator.plot.hist(bins=int(median_duration_per_annotator.max())*2, figsize=(10, 3))
plt.xlabel("Median Duration of Annotations (s)")
plt.show()

# %% [markdown]
# ## Merging two Tables
#
# We might want to concatenate the keywords associated with each audio file (in `metadata`) to the annotations.

# %%
metadata[['keywords']].head(1)
# Out:
#                                                      keywords
# filename
# 221934.mp3  engine, christian, field-recording, people, la...

# %%
annotations[['filename', 'onset', 'offset', 'text']].head(1)
# Out:
#      filename      onset     offset  \
# 0  387455.mp3  25.777629  26.516667
#
#                                                 text
# 0  Light metallic sound like a light metallic cha...

# %% [markdown]
# <img src="https://pandas.pydata.org/docs/_images/merging_concat_axis1_join_axes.png"/> (Figure taken from pandas.pydata.org)

# %%
annotations = annotations.merge(metadata, on="filename", how="left", suffixes=('', '_metadata'))
annotations[["filename", "duration", "text", "keywords"]].head(1)
# Out:
#      filename  duration                                               text  \
# 0  387455.mp3  0.739038  Light metallic sound like a light metallic cha...
#
#                                             keywords
# 0  ol, Motor, Bus, Micro, Peru, Espa, Wallas, Pub...

# %% [markdown]
# - `on` specifies how to connect the two tables
# - if there were filenames in metadata that are not in annotations, `how="left"` would simply ignore them; more info [here](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html).
# - `suffixes` defines a suffix in case two columns have the same name

# %% [markdown]
# # Audio Features
#
# We precomputed the audio features with an [audio embedding model](https://arxiv.org/pdf/2409.09546) for you.
#
# There is one feature tensor stored as a file in the `MLPC2025_dataset`
#
# ```
# MLPC2025_Dataset/
# ├── audio/
# │   ├── 0.mp3
# │   ├── 1.mp3
# │   ├── ...
# ├── audio_features/ <--- load this
# │   ├── 0.npz
# │   ├── 1.npz
# │   ├── ...
# ├── metadata.csv
# └── annotations.csv
# ```
#
# The exact meaning of the individual features is not too critical for now - we'll introduce them next time.

# %%
# IF YOUR PC CANNOT HANDLE ALL FILES, UNCOMMENT THESE LINES TO ONLY LOAD 500 FILES
# metadata = metadata.sample(frac=0.25, replace=False, random_state=974471)
# annotations = annotations.loc[annotations["filename"].isin(metadata.index)]

# %% [markdown]
# ## Loading the Audio Features
#
# Audio feature tensors can be loaded via `np.load(path_to_feature_file)["embeddings"]`:
# - iterate over all rows in the metadata file
# - store each numpy tensor in a dictionary
# - use the filename as a key

# %%
metadata[['keywords']].head(n=2)
# Out:
#                                                      keywords
# filename
# 221934.mp3  engine, christian, field-recording, people, la...
# 396529.mp3  Playground, Child-Play, Ambience, Hammering, N...

# %%
import numpy as np

audio_features = {}

for idx, row in metadata.iterrows():
    file_name = idx.replace("mp3", "npz")
    path_to_feature_file = os.path.join(PATH_TO_DATASET, "audio_features", file_name)
    
    features = np.load(path_to_feature_file)["embeddings"]
    audio_features[idx] = features
print("Number of feature files:", len(audio_features))
# Out:
# Number of feature files: 2000

# %% [markdown]
# ## Some Statistics and a Visualization

# %%
feature_tensor = audio_features[metadata.index[0]]
print("Shape of feature tensor:", feature_tensor.shape)
print("Time steps: \t\t", len(feature_tensor))
print("Feature vector size: \t", feature_tensor.shape[1])
# Out:
# Shape of feature tensor: (171, 768)
# Time steps: 		 171
# Feature vector size: 	 768

# %%
plt.imshow(feature_tensor.T)
plt.xlabel("Time (s)")
plt.ylabel("Featues")
plt.xticks(np.arange(0,20,5)/0.12, np.arange(0,20,5))
plt.show()

# %% [markdown]
# ## Feature Normalization
#
# For normalization, we typically compute the mean and the standard deviation of all 768 features along the time dimension.
#
# The easiest way to do this is by concatenating all feature tensors along the time dimension via `np.concatenate`:

# %%
concatenated_feature_tensor = np.concatenate(list(audio_features.values()), axis=0)
print("Shape of all feature tensors concatenated:", concatenated_feature_tensor.shape)
# Out:
# Shape of all feature tensors concatenated: (375176, 768)

# %%
plt.imshow(concatenated_feature_tensor[:5000].T) # transposed for visualization
plt.xlabel("Time (s)")
plt.ylabel("Featues")
plt.xticks(np.arange(0,700,100)/0.12, np.arange(0,700,100))
plt.show()

# %% [markdown]
# Use scikit-learn's `preprocessing.StandardScaler()` to compute mean and standard deviation:

# %%
from sklearn import preprocessing
scaler = preprocessing.StandardScaler().fit(concatenated_feature_tensor)

del concatenated_feature_tensor # we don't need that one anymore ...

# %% [markdown]
# - fit takes a numpy array of shape `(num_samples, num_features)`
# - internally, it computes the mean and standard deviation over the first dimension for normalization
# - later, we can use `scaler.transform(feature_tensor)` to normalize a feature tensor

# %% [markdown]
# ## Normalized Features
#
# Here's a comparison between the original, and the normalized features:

# %%
fig, axes = plt.subplots(1, 2, figsize=(4, 4))  # Create a figure with 1 row and 2 columns
axes[0].imshow(feature_tensor.T)
axes[0].set_xlabel("Time (s)"); axes[0].set_ylabel("Features")
axes[0].set_xticks(np.arange(0, 20, 5) / 0.12)
axes[0].set_xticklabels(np.arange(0, 20, 5))
axes[0].set_title("Original Features")
axes[1].imshow(scaler.transform(feature_tensor).T)
axes[1].set_xlabel("Time (s)"); axes[1].set_ylabel("Features")
axes[1].set_xticks(np.arange(0, 20, 5) / 0.12)
axes[1].set_xticklabels(np.arange(0, 20, 5))
axes[1].set_title("Scaled Features")
plt.tight_layout(); plt.show()  # Adjust layout for better spacing

# %% [markdown]
# # Temporal Annotations
#
# Each annotation is associated with a specific region ins a file (onset and offset):

# %%
i = 5
plt.imshow(scaler.transform(audio_features[annotations.iloc[i]['filename']]).T)
plt.title(annotations.iloc[i]['text'])
plt.axvline(x=annotations.iloc[i]['onset'] // 0.12, color='r')
plt.axvline(x=annotations.iloc[i]['offset'] // 0.12, color='r')
plt.xlabel("Time (s)")
plt.ylabel("Featues")
plt.xticks(np.arange(0,20,5)/0.12, np.arange(0,20,5))
plt.show()

# %% [markdown]
# ## Extracting Audio Features for Each Annotated Region
#
# To extract features for this particular region, you can use `get_features_of_annotation`:
# - the function **selects the correct region** in the feature tensor
# - **aggregates** the features over the time dimension to represent all regions as a 768-dimensional vector

# %%
import math

def get_features_of_annotation(
    onset: float, 
    offset: float, 
    audio_features: np.ndarray, 
    scaler: preprocessing.StandardScaler = None
) -> np.ndarray:

    RESOLUTION = 0.12 # temporal resolution of the features is 120 ms
    start_idx = math.floor(onset / RESOLUTION)
    offset_idx = math.ceil(offset / RESOLUTION)
    
    audio_features = audio_features[start_idx:offset_idx, :]
    if scaler is not None:
        audio_features = scaler.transform(audio_features)    
    return audio_features.mean(axis=0)

# %% [markdown]
# Compute one 768-dimensional vector for each annotated region:

# %%
X = np.zeros((len(annotations), 768))
for i, row in annotations.iterrows():
    X[i] = get_features_of_annotation(row['onset'], row['offset'], audio_features[row['filename']], scaler)

# %%
print("Audio Features of annotated regions:", X.shape)
# Out:
# Audio Features of annotated regions: (7975, 768)

# %% [markdown]
# # Clustering the Audio Features
#
# Let's see if we can identify meaningful clusters of audio regions.
#
# `sklearn.cluster` offers a variety of clustering algorithms; you can find an overview [here](https://scikit-learn.org/stable/modules/clustering.html).
#
# We'll use k-means clustering with 25 cluster centers:

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=25, max_iter=300, random_state=14124).fit(X)
clusters_assignment = kmeans.predict(X)
annotations['cluster_assignment'] = clusters_assignment
annotations['cluster_assignment'].head(5)
# Out:
# 0     7
# 1     5
# 2    21
# 3    18
# 4     5
# Name: cluster_assignment, dtype: int32

# %% [markdown]
# - use `fit` to learn the cluster centers; the output is a KMeans object containing the learned cluster centers `.cluster_centers_`
# - use `.predict(feature_vecors)` to find the cluster assignment for the regions
# - in your experiments, you will need to play around with the number of cluster centers; 25 is probably not the best choice
# - use `random_state` to make the outcome reproducible

# %% [markdown]
# ## Assigning Meaning to Clusters
#
# We've found 25 clusters. To which categories do they correspond?

# %%
counts = annotations["cluster_assignment"].value_counts(sort=False).sort_index()
counts.plot(kind="bar", figsize=(8, 3))
plt.show()

# %% [markdown]
# We need lablels for the annotated regions... use the text!

# %% [markdown]
# ##  Use the textual annotations to create approximate labels
#
# **Search for keywords in the text annotations** (e.g., rain, thunder, storm, ...).
#
# If the text annotation contains a relevant word (e.g., "It is raining cats and dogs."), we can assume that it belongs to the desired category.
#
# Let's define a function `is_bad_weather` which returns `True` if the annotation contains one of these keywords and `False` otherwise.

# %%
def is_bad_weather(text_annotation):
    keywords = ["rain", "storm", "thunder", "lightning"]
    return any([kw in text_annotation for kw in keywords])

# %% [markdown]
# Use `.tranform` to convert the `text` column to our labels.

# %%
annotations['bad_weather'] = annotations["text"].transform(is_bad_weather)
annotations['bad_weather'].value_counts()
# Out:
# bad_weather
# False    7656
# True      319
# Name: count, dtype: int64

# %% [markdown]
# ## Let's check the result

# %%
# goup by cluster and bad_weater, get size of eah group and then pivot bad weather from index to column
counts = annotations[["cluster_assignment", "bad_weather"]].groupby(["cluster_assignment", "bad_weather"]).size().unstack()

counts.plot(kind="bar", figsize=(8, 3))
plt.show()

# %% [markdown]
# Let's check the two clusters..

# %% [markdown]
# ## Let's check the result (cont'd)
# Check Cluster 8

# %%
annotations.loc[annotations['cluster_assignment'] == 8, 'text'].head(n=5)
# Out:
# 40                                A sudden loud thunder
# 62              Thunder rumbling quietly in the distance
# 202                              thunder in the distance
# 216    Thunder slowly building up until it reaches a ...
# 244    Rain gradually decreasing in intensity, fading...
# Name: text, dtype: object

# %% [markdown]
# Check Cluster 6

# %%
annotations.loc[annotations['cluster_assignment'] ==  6, 'text'].head(n=3)
# Out:
# 155    Train horn followed by the sound of the train ...
# 159                A train wagon crossing gaps in rails.
# 180    A train rushes through the station at high spe...
# Name: text, dtype: object

# %% [markdown]
# ## Task 2: Can you improve 'is_bad_weather' to give a more accurate label? (5 minutes)
# - copy `is_bad_weather` from above and try to improve it

# %%
def is_bad_weather(text_annotation):
    keywords = [" rain", "storm", "thunder", "lightning"]
    return any([kw in text_annotation for kw in keywords])
    # return False

# %% [markdown]
# Use this to verify your implementation:

# %%
annotations["bad_weather"] = annotations["text"].transform(is_bad_weather)
counts = annotations[["cluster_assignment", "bad_weather"]].groupby(["cluster_assignment", "bad_weather"]).size().unstack()

counts.plot(kind="bar", figsize=(8, 3))
plt.show()

# %%
annotations.loc[annotations['cluster_assignment'] ==  8, ['text', 'bad_weather']].head(n=3)
# Out:
#                                          text  bad_weather
# 40                     A sudden loud thunder          True
# 62   Thunder rumbling quietly in the distance        False
# 202                   thunder in the distance         True

# %% [markdown]
# # Visualization
#
# Clusters in the 768-dimensional vector space are hard to visualize.
#
# Let's project them to points on a two-dimensional plane in a way that preserves the neighborhood relationships between points.
# - optimization criterion: points that are close to each other in the 768-dimension space, should be close in the 2-dimensional space
#
# [t-distributed Stochastic Neighborhood Embedding](https://distill.pub/2016/misread-tsne/) (TSNE) does exactly that!
#
# Let's use scikit-learn's TSNE class to embed the audio feature vectors of the annotations.

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, perplexity=30, random_state=42).fit_transform(X)
tsne.shape
# Out:
# (7975, 2)

# %% [markdown]
# - use `fit_transform` to learn the embedding; it returns the embedded vecors
# - `n_components` is the number of dimensions after projection (use 2 for 2D plots or 3 for 3D plots)
# - `perplexity` is a hyper-parameters that related to the size of the neighborhood; you need to find a good choice here
# - `random_state` seeds the RNG and makes the result reproducible

# %% [markdown]
# ## Scatter plot
#
# Let's visualize the results as a scatter plot:

# %%
np.random.seed(2982)
sample_indices = np.random.choice(len(X), size=min(500, len(X)), replace=False) # Subsample data points to reduce visual clutter
tsne_sampled = tsne[sample_indices]
y_sampled = annotations["bad_weather"].loc[sample_indices]
plt.figure(figsize=(5, 5))
scatter = plt.scatter(tsne_sampled[:, 0], tsne_sampled[:, 1], c=y_sampled, alpha=0.7)
handles, _ = scatter.legend_elements() # Create a legend
plt.legend(handles, ['probably not bad weather', 'bad weather'], title="Classes", ncols=1, loc='center right', bbox_to_anchor=(1.65, 0.5))
plt.xlabel("t-SNE Dimension 1"); plt.ylabel("t-SNE Dimension 2"); plt.title(f"t-SNE with perplexity 30")
plt.show()

# %% [markdown]
# ## Task 3: Can you find a cluster of insect buzzing sounds?
#
# Define a function to convert text annotations into binary labels (True/ False).
# - search for keywords such as "buzzing", "bee ", "bees ", or "insect"

# %%
def is_insect(text_annotation):
    keywords = ["buzzing", "bee ", "bees ", "insect"]
    return any([kw in text_annotation for kw in keywords])
    # return None
        
annotations['insect'] = annotations["text"].transform(is_insect)

# %% [markdown]
# ## Check the insect annotations found
#
# If this list contains a lot of unrelated sounds, you might want to revise your `is_insect` function:

# %%
annotations.loc[annotations["insect"], "text"].head(n=10)
# Out:
# 22     Insect flying and buzzing, at first only quiet...
# 113                      bee micro buzzing very silently
# 130                 unstable sound of bee buzzing nearby
# 135    An insect flying by with a high-pitched buzzin...
# 190    Two bees trying to escape a fly net in the woo...
# 198                  A few bees are buzzing repeatedly.
# 263                         mosquitos flying and buzzing
# 375                an insect buzzing and flying overhead
# 389                                  fly buzzing quietly
# 398    Short and quiet high-pitch buzzing of flying i...
# Name: text, dtype: object

# %% [markdown]
# ## Check if there's a cluster that corresponds to the insect sounds
#
# One of the clusters should have a high number of insect related text annotations.

# %%
# goup by cluster and bad_weater, get size of eah group and then pivot bad weather from index to column
counts = annotations[["cluster_assignment", "insect"]].groupby(["cluster_assignment", "insect"]).size().unstack()

counts.plot(kind="bar", figsize=(8, 3))
plt.show()

# %%
annotations.loc[annotations["cluster_assignment"] == 24, "text"].head(n=5)
# Out:
# 22     Insect flying and buzzing, at first only quiet...
# 112                     fly buzzes loudly at close range
# 113                      bee micro buzzing very silently
# 130                 unstable sound of bee buzzing nearby
# 190    Two bees trying to escape a fly net in the woo...
# Name: text, dtype: object

# %% [markdown]
# ## Scatter Plot
#
# Is there also a cluster in the low-dimensional projection?

# %%
tsne_sampled = tsne[sample_indices]
y_sampled = annotations["insect"].loc[sample_indices]
plt.figure(figsize=(5, 5))
scatter = plt.scatter(tsne_sampled[:, 0], tsne_sampled[:, 1], c=y_sampled, alpha=0.7)
for i, (label, bad) in enumerate(zip(annotations["text"].loc[sample_indices], annotations["insect"].loc[sample_indices])): # Add labels for subsampled points
    if bad:
        plt.text(tsne_sampled[i, 0], tsne_sampled[i, 1], str(label), fontsize=8, alpha=0.7)
        
handles, _ = scatter.legend_elements() # Create a legend
plt.legend(handles, ['probably not an insect', 'insect'], title="Classes", ncols=1, loc='center right', bbox_to_anchor=(1.65, 0.5))
plt.xlabel("t-SNE Dimension 1"); plt.ylabel("t-SNE Dimension 2"); plt.title(f"t-SNE with perplexity 30")
plt.show()

# %% [markdown]
# # Exploration Task
#
# Complete MLPC2024_dataset:
# ```
# MLPC2025_Dataset/
# ├── audio/
# │   ├── 0.mp3
# │   ├── 1.mp3
# │   ├── ...
# ├── audio_features/
# │   ├── 0.npz
# │   ├── 1.npz
# │   ├── ...
# ├── text_features/
# │   ├── ...
# ├── keywords_features/
# │   ├── ...
# ├── metadata.csv
# └── annotations.csv
# ```
#
# - more data (12k instead of 2k)
# - text embeddings
# - keyword embeddings
# - additional audio features
#
# **Data exploration task will be presented next week!**
